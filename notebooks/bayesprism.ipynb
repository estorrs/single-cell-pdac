# %%
import os
import anndata
import pandas as pd
import numpy as np
import scanpy as sc

from mgitools.os_helpers import listfiles

# %% [markdown]
# #### prepare inputs for cibersortx

# %%
sct = sc.read_h5ad('../data/single_cell/checkpoints/non_eus_processed.h5ad')
sct
# Out:
# AnnData object with n_obs × n_vars = 113052 × 29227
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'nCount_SCT', 'nFeature_SCT', 'CELL', 'CONDITION', 'Patient', 'Type', 'Cell_type', 'integrated_snn_res.0.75', 'seurat_clusters', 'sample_id', 'cell_type', 'pollock_cell_type', 'dataset', 'Bailey | ADEX | score', 'Bailey | Squamous-like | score', 'Bailey | Pancreatic-Progenitor | score', 'Bailey | Immunogenic | score', 'Collison | Exocrine-like | score', 'Collison | Quasi-Mesenchymal | score', 'Collison | Classical | score', 'Moffit | Basal | score', 'Moffit | Classical | score', 'subTME | deserted | score', 'subTME | reactive | score', 'raghaven | scBasal | score', 'raghaven | scClassical | score', 'raghaven | IC | score', 'raghaven | Pericyte-like | score', 'raghaven | Fibroblast-like | score', 'raghaven | Inflammatory | score', 'raghaven | TAM-FCN1 | score', 'raghaven | TAM-C1QC | score', 'raghaven | TAM-SPP1 | score', 'elyada | myCAF | score', 'elyada | iCAF | score', 'elyada | apCAF | score', 'ben-porath | ES exp1 | score', 'ben-porath | ES exp2 | score', 'ben-porath | Nanog targets | score', 'ben-porath | Oct4 targets | score', 'ben-porath | Sox2 targets | score', 'ben-porath | NOS targets | score', 'ben-porath | NOS TFs | score', 'ben-porath | Suz12 targets | score', 'ben-porath | Eed targets | score', 'ben-porath | H3K27 bound | score', 'ben-porath | PRC2 targets | score', 'ben-porath | Myc targets1 | score', 'ben-porath | Myc targets2 | score', 'ben-porath | Genes functionally associated with proliferation | score', 'ben-porath | Cycling genes | score', 'ben-porath | Proliferation cluster | score', 'ben-porath | ES TFs | score', 'wong | stem_core | score', 'sanchez-vega | Cell Cycle | score', 'sanchez-vega | HIPPO | score', 'sanchez-vega | MYC | score', 'sanchez-vega | NOTCH | score', 'sanchez-vega | NRF2 | score', 'sanchez-vega | PI3K | score', 'sanchez-vega | TGF-Beta | score', 'sanchez-vega | RTK RAS | score', 'sanchez-vega | TP53 | score', 'sanchez-vega | WNT | score', 'Chan-Seng-Yue | Signature 2 (Basal-like A) | score', 'Chan-Seng-Yue | Signature 10 (Basal-like B) | score', 'Chan-Seng-Yue | Signature 1 (Classical A) | score', 'Chan-Seng-Yue | Signature 6 (Classical B) | score', 'MCPcounter | MCPcounter_B lineage | score', 'MCPcounter | MCPcounter_CD8 T cells | score', 'MCPcounter | MCPcounter_Cytotoxic lymphocytes | score', 'MCPcounter | MCPcounter_Endothelial cells | score', 'MCPcounter | MCPcounter_Fibroblasts | score', 'MCPcounter | MCPcounter_Monocytic lineage | score', 'MCPcounter | MCPcounter_Myeloid dendritic cells | score', 'MCPcounter | MCPcounter_NK cells | score', 'MCPcounter | MCPcounter_Neutrophils | score', 'MCPcounter | MCPcounter_T cells | score', 'Immunophenogram | Immunophenogram_Activated B cell: Adaptive | score', 'Immunophenogram | Immunophenogram_Activated CD4 T cell: Adaptive | score', 'Immunophenogram | Immunophenogram_Activated CD8 T cell: Adaptive | score', 'Immunophenogram | Immunophenogram_Central memory CD4 T cell: Adaptive | score', 'Immunophenogram | Immunophenogram_Central memory CD8 T cell: Adaptive | score', 'Immunophenogram | Immunophenogram_Effector memeory CD4 T cell: Adaptive | score', 'Immunophenogram | Immunophenogram_Effector memeory CD8 T cell: Adaptive | score', 'Immunophenogram | Immunophenogram_Gamma delta T cell: Adaptive | score', 'Immunophenogram | Immunophenogram_Immature  B cell: Adaptive | score', 'Immunophenogram | Immunophenogram_Memory B cell: Adaptive | score', 'Immunophenogram | Immunophenogram_Regulatory T cell: Adaptive | score', 'Immunophenogram | Immunophenogram_T follicular helper cell: Adaptive | score', 'Immunophenogram | Immunophenogram_Type 1 T helper cell: Adaptive | score', 'Immunophenogram | Immunophenogram_Type 17 T helper cell: Adaptive | score', 'Immunophenogram | Immunophenogram_Type 2 T helper cell: Adaptive | score', 'Immunophenogram | Immunophenogram_Activated dendritic cell: Innate | score', 'Immunophenogram | Immunophenogram_CD56bright natural killer cell: Innate | score' ...
#     uns: 'cell_type_colors', 'cell_type_specific_colors', 'cell_type_specific_v2_colors', 'cell_type_specific_v3_colors', 'cytogenes', 'cytogenes_mesenchymal', 'dataset_colors', 'pollock_cell_type_colors', 'sample_id_colors'
#     obsm: 'X_umap', 'X_umap_pollock', 'pollock_prediction_probs'
#     layers: 'counts'

# %%
set(sct.obs['cell_type_specific_final'])
# Out:
# {'ADM',
#  'Acinar',
#  'B cell',
#  'CD4 T cell',
#  'CD8 T cell',
#  'CD8 T cell - Exhausted',
#  'DC',
#  'Endocrine',
#  'Endothelial',
#  'Exclude - Ambiguous',
#  'Exclude - Singleton',
#  'Immune - Proliferating',
#  'Malignant - Basal',
#  'Malignant - Classical',
#  'Malignant - IC',
#  'Malignant - Proliferating Basal',
#  'Malignant - Proliferating Classical',
#  'Malignant - Proliferating IC',
#  'Mast',
#  'NK',
#  'Plasma',
#  'Stellate',
#  'TAM - C1QC',
#  'TAM - FCN1',
#  'TAM - Proliferating',
#  'TAM - SPP1',
#  'Treg',
#  'iCAF',
#  'myCAF'}

# %%
sct = sct[[True if 'Exclude' not in ct else False
          for ct in sct.obs['cell_type_specific_final']]]
sct.shape
# Out:
# (104486, 29227)

# %%
ref_adata = anndata.AnnData(X=sct.layers['counts'],
                            obs=sct.obs[['sample_id', 'cell_type_specific_final', 'cell_type_specific_final']],
                           var=sct.var)
ref_adata
# Out:
# /diskmnt/Projects/Users/estorrs/miniconda3/envs/single-cell-pdac/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   This is separate from the ipykernel package so we can avoid doing imports until
# AnnData object with n_obs × n_vars = 104486 × 29227
#     obs: 'sample_id', 'cell_type_specific_final', 'cell_type_specific_final'

# %%
ref_adata.obs.columns = ['patient.id', 'cell.type', 'cell.subtype']
ref_adata.obs
# Out:
#                                                     patient.id  \
# 1555-tumor_AAACCTGAGACCTAGG-1                       1555-tumor
# 1555-tumor_AAACCTGAGTGCGTGA-1                       1555-tumor
# 1555-tumor_AAACCTGCATCCCACT-1                       1555-tumor
# 1555-tumor_AAACCTGGTCATGCAT-1                       1555-tumor
# 1555-tumor_AAACCTGTCCGGGTGT-1                       1555-tumor
# ...                                                        ...
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...       G9903
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...       G9903
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCAAG...       G9903
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCACA...       G9903
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCATC...       G9903
#
#                                                                 cell.type  \
# 1555-tumor_AAACCTGAGACCTAGG-1                                          NK
# 1555-tumor_AAACCTGAGTGCGTGA-1                       Malignant - Classical
# 1555-tumor_AAACCTGCATCCCACT-1                                        Treg
# 1555-tumor_AAACCTGGTCATGCAT-1                                      B cell
# 1555-tumor_AAACCTGTCCGGGTGT-1                                  CD8 T cell
# ...                                                                   ...
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...                   iCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...                  myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCAAG...                  myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCACA...                  myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCATC...         Malignant - IC
#
#                                                              cell.subtype
# 1555-tumor_AAACCTGAGACCTAGG-1                                          NK
# 1555-tumor_AAACCTGAGTGCGTGA-1                       Malignant - Classical
# 1555-tumor_AAACCTGCATCCCACT-1                                        Treg
# 1555-tumor_AAACCTGGTCATGCAT-1                                      B cell
# 1555-tumor_AAACCTGTCCGGGTGT-1                                  CD8 T cell
# ...                                                                   ...
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...                   iCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...                  myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCAAG...                  myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCACA...                  myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCATC...         Malignant - IC
#
# [104486 rows x 3 columns]

# %%
# # subsample to 5k cells per cell type
# cell_types = sorted(set(sct.obs['cell_type_specific_final']))
# pool = []
# for ct in cell_types:
#     if 'Exclude' not in ct:
#         f = sct[sct.obs['cell_type_specific_final']==ct]
#         ids = list(np.random.choice(f.obs.index.to_list(), size=min(500, f.shape[0]), replace=False))
#         pool += ids
# f = ref_adata[pool]
# f = f[:, np.sum(f.X, axis=0)>10]
# f

# %%
f = ref_adata

# %%
bulk_fps = sorted(listfiles('../data/bulk_rna_seq/', regex=r'bulk_rna_seq/[^/]+_counts.txt$'))
bulk_fps
# Out:
# ['../data/bulk_rna_seq/bailey_counts.txt',
#  '../data/bulk_rna_seq/cptac_counts.txt',
#  '../data/bulk_rna_seq/kirby_counts.txt',
#  '../data/bulk_rna_seq/tcga_counts.txt']

# %%
genes = set(f.var.index.to_list())
for fp in bulk_fps:
    df = pd.read_csv(fp, sep='\t', index_col=0)
    genes.intersection_update(set(df.index.to_list()))
    print(fp, len(genes))
len(genes)
# Out:
# ../data/bulk_rna_seq/bailey_counts.txt 18749
# ../data/bulk_rna_seq/cptac_counts.txt 18263
# ../data/bulk_rna_seq/kirby_counts.txt 15118
# ../data/bulk_rna_seq/tcga_counts.txt 15081
# 15081

# %%
f = f[:, sorted(genes)]
f
# Out:
# View of AnnData object with n_obs × n_vars = 104486 × 15081
#     obs: 'patient.id', 'cell.type', 'cell.subtype'

# %%
f.obs
# Out:
#                                                     patient.id  \
# 1555-tumor_AAACCTGAGACCTAGG-1                       1555-tumor
# 1555-tumor_AAACCTGAGTGCGTGA-1                       1555-tumor
# 1555-tumor_AAACCTGCATCCCACT-1                       1555-tumor
# 1555-tumor_AAACCTGGTCATGCAT-1                       1555-tumor
# 1555-tumor_AAACCTGTCCGGGTGT-1                       1555-tumor
# ...                                                        ...
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...       G9903
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...       G9903
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCAAG...       G9903
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCACA...       G9903
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCATC...       G9903
#
#                                                                 cell.type  \
# 1555-tumor_AAACCTGAGACCTAGG-1                                          NK
# 1555-tumor_AAACCTGAGTGCGTGA-1                       Malignant - Classical
# 1555-tumor_AAACCTGCATCCCACT-1                                        Treg
# 1555-tumor_AAACCTGGTCATGCAT-1                                      B cell
# 1555-tumor_AAACCTGTCCGGGTGT-1                                  CD8 T cell
# ...                                                                   ...
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...                   iCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...                  myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCAAG...                  myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCACA...                  myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCATC...         Malignant - IC
#
#                                                              cell.subtype
# 1555-tumor_AAACCTGAGACCTAGG-1                                          NK
# 1555-tumor_AAACCTGAGTGCGTGA-1                       Malignant - Classical
# 1555-tumor_AAACCTGCATCCCACT-1                                        Treg
# 1555-tumor_AAACCTGGTCATGCAT-1                                      B cell
# 1555-tumor_AAACCTGTCCGGGTGT-1                                  CD8 T cell
# ...                                                                   ...
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...                   iCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...                  myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCAAG...                  myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCACA...                  myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCATC...         Malignant - IC
#
# [104486 rows x 3 columns]

# %%
# enter sample id for tumor subtype
f.obs['cell.subtype'] = [s if 'Malignant' in c else c for s, c in zip(f.obs['patient.id'], f.obs['cell.subtype'])]
f.obs
# Out:
# /diskmnt/Projects/Users/estorrs/miniconda3/envs/single-cell-pdac/lib/python3.7/site-packages/ipykernel_launcher.py:2: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#                                                     patient.id  \
# 1555-tumor_AAACCTGAGACCTAGG-1                       1555-tumor
# 1555-tumor_AAACCTGAGTGCGTGA-1                       1555-tumor
# 1555-tumor_AAACCTGCATCCCACT-1                       1555-tumor
# 1555-tumor_AAACCTGGTCATGCAT-1                       1555-tumor
# 1555-tumor_AAACCTGTCCGGGTGT-1                       1555-tumor
# ...                                                        ...
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...       G9903
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...       G9903
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCAAG...       G9903
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCACA...       G9903
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCATC...       G9903
#
#                                                                 cell.type  \
# 1555-tumor_AAACCTGAGACCTAGG-1                                          NK
# 1555-tumor_AAACCTGAGTGCGTGA-1                       Malignant - Classical
# 1555-tumor_AAACCTGCATCCCACT-1                                        Treg
# 1555-tumor_AAACCTGGTCATGCAT-1                                      B cell
# 1555-tumor_AAACCTGTCCGGGTGT-1                                  CD8 T cell
# ...                                                                   ...
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...                   iCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...                  myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCAAG...                  myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCACA...                  myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCATC...         Malignant - IC
#
#                                                    cell.subtype
# 1555-tumor_AAACCTGAGACCTAGG-1                                NK
# 1555-tumor_AAACCTGAGTGCGTGA-1                        1555-tumor
# 1555-tumor_AAACCTGCATCCCACT-1                              Treg
# 1555-tumor_AAACCTGGTCATGCAT-1                            B cell
# 1555-tumor_AAACCTGTCCGGGTGT-1                        CD8 T cell
# ...                                                         ...
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...         iCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTC...        myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCAAG...        myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCACA...        myCAF
# G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCATC...        G9903
#
# [104486 rows x 3 columns]

# %%
f.obs.index = ['X' + x for x in f.obs.index.to_list()]
f.obs.index.name = 'cell.id'

# %%
f.obs.to_csv('../data/deconvolution/bayesprism/inputs/sc_ref_annotations.txt', sep='\t')

# %%
# save counts for cytotrace
df = pd.DataFrame(data=f.X.toarray(), columns=f.var.index.to_list(),
                  index=f.obs.index.to_list(), dtype=int)
df = df.transpose()
df.index.name = 'Gene'

df
# Out:
#         X1555-tumor_AAACCTGAGACCTAGG-1  X1555-tumor_AAACCTGAGTGCGTGA-1  \
# Gene
# A1BG                                 0                               0
# A1CF                                 0                               0
# A2M                                  0                               0
# A2ML1                                0                               0
# A4GALT                               0                               0
# ...                                ...                             ...
# ZXDC                                 0                               1
# ZYG11A                               0                               0
# ZYG11B                               0                               1
# ZYX                                  1                               4
# ZZEF1                                0                               0
#
#         X1555-tumor_AAACCTGCATCCCACT-1  X1555-tumor_AAACCTGGTCATGCAT-1  \
# Gene
# A1BG                                 0                               0
# A1CF                                 0                               0
# A2M                                  0                               0
# A2ML1                                0                               0
# A4GALT                               0                               0
# ...                                ...                             ...
# ZXDC                                 0                               0
# ZYG11A                               0                               0
# ZYG11B                               0                               0
# ZYX                                  0                               0
# ZZEF1                                0                               0
#
#         X1555-tumor_AAACCTGTCCGGGTGT-1  X1555-tumor_AAACGGGAGACAATAC-1  \
# Gene
# A1BG                                 0                               0
# A1CF                                 0                               0
# A2M                                  0                               0
# A2ML1                                0                               0
# A4GALT                               0                               0
# ...                                ...                             ...
# ZXDC                                 0                               0
# ZYG11A                               0                               0
# ZYG11B                               0                               0
# ZYX                                  0                               1
# ZZEF1                                1                               0
#
#         X1555-tumor_AAACGGGAGGCGCTCT-1  X1555-tumor_AAACGGGAGGGTATCG-1  \
# Gene
# A1BG                                 0                               0
# A1CF                                 0                               0
# A2M                                  0                               0
# A2ML1                                0                               0
# A4GALT                               0                               0
# ...                                ...                             ...
# ZXDC                                 0                               0
# ZYG11A                               0                               0
# ZYG11B                               0                               0
# ZYX                                  0                               0
# ZZEF1                                0                               0
#
#         X1555-tumor_AAACGGGGTGAGTGAC-1  X1555-tumor_AAACGGGTCTCGCATC-1  ...  \
# Gene                                                                    ...
# A1BG                                 1                               0  ...
# A1CF                                 0                               0  ...
# A2M                                  4                               0  ...
# A2ML1                                0                               0  ...
# A4GALT                               1                               0  ...
# ...                                ...                             ...  ...
# ZXDC                                 0                               0  ...
# ZYG11A                               0                               0  ...
# ZYG11B                               0                               0  ...
# ZYX                                  4                               0  ...
# ZZEF1                                0                               0  ...
#
#         XG9903_filtered_gene_bc_matrices_h5.h5_TTTGCGCCACAGGAGT-1  \
# Gene
# A1BG                                                    0
# A1CF                                                    0
# A2M                                                     0
# A2ML1                                                   0
# A4GALT                                                  0
# ...                                                   ...
# ZXDC                                                    0
# ZYG11A                                                  0
# ZYG11B                                                  0
# ZYX                                                     2
# ZZEF1                                                   0
#
#         XG9903_filtered_gene_bc_matrices_h5.h5_TTTGCGCGTACCGTAT-1  \
# Gene
# A1BG                                                    0
# A1CF                                                    0
# A2M                                                     0
# A2ML1                                                   0
# A4GALT                                                  0
# ...                                                   ...
# ZXDC                                                    0
# ZYG11A                                                  0
# ZYG11B                                                  0
# ZYX                                                     0
# ZZEF1                                                   0
#
#         XG9903_filtered_gene_bc_matrices_h5.h5_TTTGCGCGTGCAACTT-1  \
# Gene
# A1BG                                                    0
# A1CF                                                    0
# A2M                                                     4
# A2ML1                                                   0
# A4GALT                                                  0
# ...                                                   ...
# ZXDC                                                    0
# ZYG11A                                                  0
# ZYG11B                                                  0
# ZYX                                                     0
# ZZEF1                                                   0
#
#         XG9903_filtered_gene_bc_matrices_h5.h5_TTTGCGCTCGTGGACC-1  \
# Gene
# A1BG                                                    0
# A1CF                                                    0
# A2M                                                     0
# A2ML1                                                   0
# A4GALT                                                  0
# ...                                                   ...
# ZXDC                                                    0
# ZYG11A                                                  0
# ZYG11B                                                  0
# ZYX                                                     0
# ZZEF1                                                   0
#
#         XG9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTGTTGTACAC-1  \
# Gene
# A1BG                                                    0
# A1CF                                                    0
# A2M                                                     0
# A2ML1                                                   0
# A4GALT                                                  1
# ...                                                   ...
# ZXDC                                                    0
# ZYG11A                                                  0
# ZYG11B                                                  0
# ZYX                                                     2
# ZZEF1                                                   0
#
#         XG9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTCCTAGTGA-1  \
# Gene
# A1BG                                                    1
# A1CF                                                    0
# A2M                                                     0
# A2ML1                                                   0
# A4GALT                                                  0
# ...                                                   ...
# ZXDC                                                    0
# ZYG11A                                                  0
# ZYG11B                                                  0
# ZYX                                                     2
# ZZEF1                                                   0
#
#         XG9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTCTACCAGA-1  \
# Gene
# A1BG                                                    1
# A1CF                                                    0
# A2M                                                     0
# A2ML1                                                   0
# A4GALT                                                  0
# ...                                                   ...
# ZXDC                                                    0
# ZYG11A                                                  0
# ZYG11B                                                  0
# ZYX                                                     1
# ZZEF1                                                   0
#
#         XG9903_filtered_gene_bc_matrices_h5.h5_TTTGTCAAGTTGTCGT-1  \
# Gene
# A1BG                                                    1
# A1CF                                                    0
# A2M                                                     0
# A2ML1                                                   0
# A4GALT                                                  0
# ...                                                   ...
# ZXDC                                                    0
# ZYG11A                                                  0
# ZYG11B                                                  0
# ZYX                                                     0
# ZZEF1                                                   0
#
#         XG9903_filtered_gene_bc_matrices_h5.h5_TTTGTCACAACTTGAC-1  \
# Gene
# A1BG                                                    1
# A1CF                                                    0
# A2M                                                     0
# A2ML1                                                   0
# A4GALT                                                  0
# ...                                                   ...
# ZXDC                                                    0
# ZYG11A                                                  0
# ZYG11B                                                  0
# ZYX                                                     0
# ZZEF1                                                   0
#
#         XG9903_filtered_gene_bc_matrices_h5.h5_TTTGTCATCCGAACGC-1
# Gene
# A1BG                                                    0
# A1CF                                                    0
# A2M                                                     0
# A2ML1                                                   0
# A4GALT                                                  0
# ...                                                   ...
# ZXDC                                                    1
# ZYG11A                                                  0
# ZYG11B                                                  1
# ZYX                                                     2
# ZZEF1                                                   0
#
# [15081 rows x 104486 columns]

# %%
df.to_csv('../data/deconvolution/bayesprism/inputs/sc_ref_counts.txt', sep='\t')

# %%
# f.obs['cell_ID'] = f.obs.index.to_list()
# f.obs['tumor_flag'] = [1 if 'Malignant' in ct else 0 for ct in f.obs['cell.type']]
# f.obs['cell_type'] = f.obs['cell.type']
# f.obs = f.obs[['cell_ID', 'cell_type', 'tumor_flag']]
# f.obs

# %%
# f.write_h5ad('../data/deconvolution/bayesprism/inputs/sc_ref_500per.h5ad')

# %%
bulk_fps = sorted(listfiles('../data/bulk_rna_seq/', regex=r'bulk_rna_seq/[^/]+_counts.txt$'))
bulk_fps
# Out:
# ['../data/bulk_rna_seq/bailey_counts.txt',
#  '../data/bulk_rna_seq/cptac_counts.txt',
#  '../data/bulk_rna_seq/kirby_counts.txt',
#  '../data/bulk_rna_seq/tcga_counts.txt']

# %%
for fp in bulk_fps:
    dataset = fp.split('/')[-1].split('_')[0]
    df = pd.read_csv(fp, sep='\t', index_col=0)
    df = df.loc[sorted(genes), :]
    df.to_csv(f'../data/deconvolution/bayesprism/inputs/{dataset}_counts.txt', sep='\t')

# %%
d = pd.read_csv('../data/sandbox/gbm_meta.txt', sep='\t')
d
# Out:
#             patient.id cell.type   cell.subtype
# PJ016.V3         PJ016     tumor  PJ016-tumor-0
# PJ016.V4         PJ016     tumor  PJ016-tumor-0
# PJ016.V5         PJ016     tumor  PJ016-tumor-3
# PJ016.V6         PJ016     tumor  PJ016-tumor-0
# PJ016.V7         PJ016     tumor  PJ016-tumor-3
# ...                ...       ...            ...
# PJ048.V3082      PJ048     tumor  PJ048-tumor-0
# PJ048.V3083      PJ048     tumor  PJ048-tumor-2
# PJ048.V3084      PJ048     tumor  PJ048-tumor-1
# PJ048.V3085      PJ048     tumor  PJ048-tumor-5
# PJ048.V3086      PJ048     tumor  PJ048-tumor-6
#
# [23793 rows x 3 columns]

# %%
set(d['cell.type'])
# Out:
# {'endothelial', 'myeloid', 'oligo', 'pericyte', 'tcell', 'tumor'}

# %%
d[d['cell.type']=='endothelial']
# Out:
#             patient.id    cell.type cell.subtype
# PJ017.V160       PJ017  endothelial  endothelial
# PJ017.V242       PJ017  endothelial  endothelial
# PJ017.V418       PJ017  endothelial  endothelial
# PJ017.V592       PJ017  endothelial  endothelial
# PJ017.V937       PJ017  endothelial  endothelial
# ...                ...          ...          ...
# PJ048.V2620      PJ048  endothelial  endothelial
# PJ048.V2830      PJ048  endothelial  endothelial
# PJ048.V2916      PJ048  endothelial  endothelial
# PJ048.V2928      PJ048  endothelial  endothelial
# PJ048.V2953      PJ048  endothelial  endothelial
#
# [492 rows x 3 columns]
