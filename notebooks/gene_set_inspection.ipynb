# %%
import os
import json

import pandas as pd
import numpy as np

# %%
gene_sets = json.load(open('../data/single_cell/gene_sets/pdac_gene_sets.json'))
gene_sets.keys()
# Out:
# dict_keys(['Bailey', 'Collison', 'Moffit', 'subTME', 'raghaven', 'elyada', 'ben-porath', 'wong', 'sanchez-vega', 'Chan-Seng-Yue', 'luoma'])

# %% [markdown]
# ###### Bailey

# %% [markdown]
# Malignant subtypes from https://pubmed.ncbi.nlm.nih.gov/26909576/

# %%
gene_sets['Bailey']
# Out:
# {'ADEX': ['MTMR7',
#   'ARX',
#   'ABCC8',
#   'CEACAM7',
#   'CACNA2D2',
#   'MAPK8IP2',
#   'SYT7',
#   'LTF',
#   'NR1H4',
#   'SLC7A14',
#   'PRSS3',
#   'CPA1',
#   'AQP8',
#   'FGL1',
#   'SERPINI2',
#   'REG1A',
#   'NR5A2',
#   'RBPJL',
#   'KIRREL2',
#   'CLPS'],
#  'Squamous-like': ['CFH',
#   'CD99',
#   'HECW1',
#   'PLXND1',
#   'RECQL',
#   'C1orf112',
#   'M6PR',
#   'FKBP4',
#   'GGCT',
#   'DBF4',
#   'SEMA3F',
#   'ANKIB1',
#   'MAD1L1',
#   'CDC27',
#   'WDR54',
#   'DPM1',
#   'NME2',
#   'UTP18',
#   'SLC25A39',
#   'TTC27'],
#  'Pancreatic-Progenitor': ['ENPP4',
#   'CFTR',
#   'CYP51A1',
#   'ABP1',
#   'LASP1',
#   'TMEM176A',
#   'ICA1',
#   'DBNDD1',
#   'CASP10',
#   'SARM1',
#   'UPF1',
#   'ACSM3',
#   'SPPL2B',
#   'PDK2',
#   'OSBPL7',
#   'TMEM98',
#   'BAIAP2L1',
#   'ALDH3B1',
#   'TTC22',
#   'FARP2'],
#  'Immunogenic': ['CD38',
#   'PDK4',
#   'FBXL3',
#   'CD79B',
#   'MYLIP',
#   'RWDD2A',
#   'ACPP',
#   'TRAF3IP3',
#   'ACAP1',
#   'ARHGAP15',
# ...

# %% [markdown]
# ###### Collison

# %% [markdown]
# Malignant subtypes from https://pubmed.ncbi.nlm.nih.gov/21460848/

# %%
gene_sets['Collison']
# Out:
# {'Exocrine-like': ['REG1B',
#   'REG3A',
#   'REG1A',
#   'PNLIPRP2',
#   'CEL',
#   'PNLIP',
#   'PLA2G1B',
#   'CELA3A',
#   'CPB1',
#   'CELA3B',
#   'CTRB2',
#   'CLPS',
#   'CELA2B',
#   'PRSS2',
#   'PRSS1',
#   'GP2',
#   'SLC3A1',
#   'CFTR',
#   'SLC4A4',
#   'SPINK1'],
#  'Quasi-Mesenchymal': ['AIM2',
#   'CALHM6',
#   'GPM6B',
#   'S100A2',
#   'KRT14',
#   'CAV1',
#   'LOX',
#   'SLC2A3',
#   'TWIST1',
#   'PAPPA',
#   'NT5E',
#   'CKS2',
#   'HMMR',
#   'SLC5A3',
#   'PMAIP1',
#   'PHLDA1',
#   'SLC16A1'],
#  'Classical': ['FERMT1',
#   'HK2',
#   'AHNAK2',
#   'TMEM45B',
#   'SDR16C5',
#   'GPRC5A',
#   'AGR2',
#   'S100P',
#   'FXYD3',
#   'ST6GALNAC1',
#   'CEACAM5',
#   'CEACAM6',
#   'TFF1',
#   'TFF3',
#   'CAPN8',
#   'FOXQ1',
#   'ELF3',
#   'ERBB3',
#   'TSPAN8',
#   'TOX3',
#   'LGALS4',
#   'PLS1',
#   'GPX2',
#   'ATP10B',
#   'MUC13']}

# %% [markdown]
# ###### Moffit

# %% [markdown]
# Malignant subtypes from https://pubmed.ncbi.nlm.nih.gov/26343385/

# %%
gene_sets['Moffit']
# Out:
# {'Basal': ['S100A2',
#   'KRT6A',
#   'CST6',
#   'GPR87',
#   'SCEL',
#   'ANXA8L2',
#   'KRT6C',
#   'SERPINB4',
#   'SERPINB3',
#   'LY6D',
#   'LY6D',
#   'PLAG1',
#   'IL20RB',
#   'C16orf74',
#   'DCBLD2',
#   'KRT17P3',
#   'HMGA2',
#   'SPRR3',
#   'SPRR1B',
#   'KRT17'],
#  'Classical': ['TM4SF5',
#   'TFF1',
#   'PLA2G10',
#   'GPX2',
#   'SPINK4',
#   'LOC400573',
#   'BTNL8',
#   'DMBT1',
#   'ATAD4',
#   'TFF3',
#   'FAM3D',
#   'LYZ',
#   'MYO1A',
#   'ANXA10',
#   'CLRN3',
#   'AKR1B10',
#   'CTSE',
#   'TSPAN8',
#   'LGALS4',
#   'REG4']}

# %% [markdown]
# ###### Chan-Seng-Yue

# %% [markdown]
# Malignant subtypes from https://pubmed.ncbi.nlm.nih.gov/31932696/

# %%
gene_sets['Chan-Seng-Yue']
# Out:
# {'Signature 2 (Basal-like A)': ['FAT2',
#   'MIR205HG',
#   'S100A9',
#   'S100A2',
#   'S100A8',
#   'KRT5',
#   'SLC2A9',
#   'RHCG',
#   'TP63',
#   'ZNF750',
#   'KRT6A',
#   'KRT14',
#   'PTHLH',
#   'TMEM45A',
#   'COL7A1',
#   'TNNT3',
#   'TMPRSS11E',
#   'ARL4D',
#   'SCPEP1',
#   'HCAR2',
#   'GSDMC',
#   'TMEM40',
#   'CYP24A1',
#   'IL20RB',
#   'GJB6',
#   'LPAR3',
#   'HCAR3',
#   'GPR87',
#   'ZNF385A',
#   'CLEC2B',
#   'FYB',
#   'COL4A6',
#   'PPP4R4',
#   'LCP1',
#   'LYPD3',
#   'ANXA8',
#   'TNC',
#   'SNAI2',
#   'FST',
#   'ANXA8L1',
#   'AIM2',
#   'LY6D',
#   'TCF7L1',
#   'KRT13',
#   'CLCA4',
#   'CAV1',
#   'MMP13',
#   'GBP6',
#   'SRGAP3',
#   'CSTA',
#   'COL4A5',
#   'ADRB2',
#   'PKP1',
#   'A4GALT',
#   'DENND2C',
#   'KRT6C',
#   'TGM1',
#   'FSCN1',
#   'ST6GALNAC2',
#   'CAPNS2',
#   'GJB2',
#   'KRT15',
#   'PADI3',
#   'NIPAL4',
#   'ACKR3',
#   'IL1A',
#   'KLC3',
#   'A2ML1',
#   'PTPN13',
#   'CNTNAP3',
#   'TLR2',
#   'FAM126A',
# ...

# %% [markdown]
# ###### Raghaven

# %% [markdown]
# Malignant and immune cell gene sets from raghaven single cell pdac paper https://www.cell.com/cell/fulltext/S0092-8674(21)01332-5

# %% [markdown]
# malignant subtypes: scBasal, scClassical, IC
#
# Fibroblast/stromal subtypes: Pericyte-like, fibroblast-like, Inflammitory
#
# Tumor associated macrophage subtypes: TAM-FCN1, TAM-C1QC, TAM-SPP1

# %%
gene_sets['raghaven']
# Out:
# {'scBasal': ['KRT6A',
#   'S100A2',
#   'KRT13',
#   'KRT17',
#   'LY6D',
#   'KRT7',
#   'KRT5',
#   'FAM83A',
#   'CD109',
#   'GAPDH',
#   'CSTA',
#   'PTPN13',
#   'MTSS1',
#   'SPRR1B',
#   'SLC2A1',
#   'CAV1',
#   'EMP1',
#   'SEMA3C',
#   'DHRS9',
#   'CAST',
#   'FLNA',
#   'SLITRK6',
#   'COL7A1',
#   'AQP3',
#   'MT2A',
#   'AHNAK2',
#   'KRT19',
#   'PKP1',
#   'YBX3',
#   'GJB5'],
#  'scClassical': ['LGALS4',
#   'CTSE',
#   'TFF1',
#   'AGR2',
#   'TSPAN8',
#   'CEACAM6',
#   'LYZ',
#   'CDH17',
#   'TFF2',
#   'CLDN18',
#   'REG4',
#   'SPINK1',
#   'SLC44A4',
#   'GPX2',
#   'ANXA10',
#   'FAM3D',
#   'TFF3',
#   'MUC13',
#   'ANXA13',
#   'CEACAM5',
#   'VSIG2',
#   'PRSS3',
#   'ALDH2',
#   'IL1R2',
#   'AGR3',
#   'CYSTM1',
#   'CAPN5',
#   'S100A6',
#   'ONECUT2',
#   'BCAS1'],
#  'IC': ['VCAM1',
#   'MALAT1',
#   'IGFBP3',
#   'SYNE2',
#   'TIMP2',
#   'TNFAIP2',
#   'NFAT5',
#   'SERPINA1',
#   'CXCL14',
#   'CX3CL1',
#   'ALPK3',
#   'ATHL1',
#   'DPYSL2',
# ...

# %% [markdown]
# ###### subTME

# %% [markdown]
# TME gene sets from subTME paper from grunwald et al https://www.cell.com/cell/fulltext/S0092-8674(21)01105-3

# %%
gene_sets['subTME']
# Out:
# {'deserted': ['STRA6',
#   'SLC29A1',
#   'SPTBN1',
#   'AAMP',
#   'SUSD2',
#   'PLEKHA6',
#   'MATN2',
#   'PHLDB1',
#   'MAP2',
#   'MAPRE3',
#   'TGM2',
#   'FGL2',
#   'ENG',
#   'DHRS7B',
#   'PAG1',
#   'ITPR1',
#   'JAG1',
#   'FBLN5',
#   'GSN',
#   'TMEM119',
#   'LTBP4',
#   'ITIH3',
#   'SYNPO',
#   'SFRP4',
#   'PLEKHA7',
#   'CADPS',
#   'THSD4',
#   'NDRG2',
#   'FRY',
#   'CARMIL1',
#   'CLMN',
#   'SORL1',
#   'ANO1',
#   'GGT5',
#   'NFIA',
#   'ABLIM1',
#   'CGNL1',
#   'ANK3',
#   'ITGBL1',
#   'NISCH',
#   'PYGM',
#   'ITIH5',
#   'IGFBP2',
#   'ARAP1',
#   'MAOB',
#   'KIF16B',
#   'MPRIP',
#   'CFC1',
#   'IGFBP5',
#   'RTN1',
#   'PDIA2',
#   'GATA6',
#   'MCF2L2',
#   'PLBD1',
#   'TIMP1',
#   'SULT1A1',
#   'ME1',
#   'SORBS2',
#   'SERPINB9',
#   'SERPINF2',
#   'APOD',
#   'NGFR',
#   'PKP2',
#   'EGFR',
#   'TMEM120A',
#   'CAPN6',
#   'TBXAS1',
#   'TACC1',
#   'PDGFRB',
#   'LTBP2',
#   'ECHDC2',
#   'CDH6',
#   'DPEP1',
#   'ANKRD44',
#   'MTTP',
# ...

# %% [markdown]
# ###### Elyada

# %% [markdown]
# CAF subtypes from https://pubmed.ncbi.nlm.nih.gov/31197017/

# %%
gene_sets['elyada']
# Out:
# {'myCAF': ['MYL9',
#   'CALD1',
#   'MMP11',
#   'HOPX',
#   'BGN',
#   'IGFBP7',
#   'TPM2',
#   'CTHRC1',
#   'ACTA2',
#   'TAGLN',
#   'INHBA',
#   'COL10A1',
#   'TPM1',
#   'POSTN',
#   'GRP',
#   'CST1'],
#  'iCAF': ['C3',
#   'DUSP1',
#   'FBLN1',
#   'LMNA',
#   'CLU',
#   'CCDC80',
#   'MYC',
#   'EFEMP1',
#   'HAS1',
#   'NR4A1',
#   'CFD',
#   'ANXA1',
#   'CXCL12',
#   'FGF7',
#   'KLF4',
#   'EMP1',
#   'GPRC5A',
#   'SRPX',
#   'MT2A',
#   'MEDAG',
#   'IGF1',
#   'MGST1',
#   'MCL1',
#   'CEBPD',
#   'S100A10',
#   'UAP1',
#   'TNXB',
#   'CEBPB',
#   'PNRC1',
#   'SOCS3',
#   'PTGDS',
#   'FOSB',
#   'NFKBIA',
#   'CXCL2',
#   'THBS1',
#   'CCL2',
#   'OGN',
#   'GSN',
#   'DPT',
#   'PLA2G2A',
#   'NAMPT',
#   'ITM2A',
#   'RGCC',
#   'JUND',
#   'NNMT',
#   'ZFP36',
#   'PIM1',
#   'CPE',
#   'GFPT2',
#   'SOD2',
#   'KDM6B',
#   'FSTL1',
#   'FBLN2',
#   'NR4A3',
#   'MFAP5',
#   'ABL2',
#   'SGK1',
#   'CILP',
#   'UGDH',
#   'FBLN5',
#   'ADAMTS1',
#   'ADH1B',
# ...

# %% [markdown]
# ###### Luoma

# %% [markdown]
# Treatment response indicative immune subtypes, including CD4, CD8, and myeloid cell states from https://www.cell.com/cell/fulltext/S0092-8674(22)00723-1#secsectitle0020

# %% [markdown]
# in cd8 t cells, ITGAE+, Cycling, and KLF2-high are indicative of potential future response to ICB therapy
#
# in cd4 t cells, CXCL+ and Cycling are indicative of potential future response to ICB therapy

# %%
gene_sets['luoma']
# Out:
# {'CD4_T_cell': {'IL7R+ CD4': ['ANXA1',
#    'IL7R',
#    'KLF2',
#    'AREG',
#    'CCR7',
#    'ZFP36L2',
#    'CD69',
#    'FOS',
#    'RPS12',
#    'EEF1B2',
#    'TCF7',
#    'PABPC1',
#    'RPL3',
#    'RPS18',
#    'GIMAP7',
#    'RPS3A',
#    'PTGER4',
#    'RPS27A',
#    'RPL36A',
#    'CXCR4',
#    'RPL13',
#    'RPS6',
#    'RPL21',
#    'TC2N',
#    'RPS5',
#    'RPS14',
#    'RPL30',
#    'RPL32',
#    'RPL9',
#    'GIMAP5',
#    'RPLP2',
#    'RPL34',
#    'RPS3',
#    'S1PR1',
#    'RPS23',
#    'EEF1A1',
#    'RPS20',
#    'RPS13',
#    'RPS21',
#    'CD55',
#    'RPL23A',
#    'RPS8',
#    'RPL38',
#    'RPL10',
#    'RPS27',
#    'RPS25',
#    'RPL13A',
#    'RPL39',
#    'RPL5',
#    'RPL27A',
#    'RPS4X',
#    'RPL35A',
#    'RPL10A',
#    'EEF1G',
#    'RPL11',
#    'TPT1',
#    'RPL19',
#    'RPLP0',
#    'RPL18A',
#    'RPL14',
#    'RPS28',
#    'NOP53',
#    'RPS2',
#    'GAS5',
#    'RPL4',
#    'RPS29',
#    'RPL36',
#    'RPL22',
#    'RPL17',
# ...

# %% [markdown]
# ###### Wong

# %% [markdown]
# Stemness genes from wong et al https://pubmed.ncbi.nlm.nih.gov/18397753/

# %%
gene_sets['wong']
# Out:
# {'stem_core': ['ABCB7',
#   'ADH5',
#   'PARP1',
#   'ADSL',
#   'AK3L1',
#   'ALDOC',
#   'SLC25A5',
#   'APEX1',
#   'BIRC5',
#   'ALDH7A1',
#   'ATP5J',
#   'ATP5O',
#   'BAX',
#   'BCAT1',
#   'CCND1',
#   'BLM',
#   'BTF3',
#   'BUB1',
#   'BUB1B',
#   'SERPINH1',
#   'CCNA2',
#   'CCNC',
#   'CCND2',
#   'CCNF',
#   'CDC2',
#   'CDC6',
#   'CDC20',
#   'CDC34',
#   'CDK4',
#   'CDKN1C',
#   'CDKN3',
#   'CTSC',
#   'RCC1',
#   'CHEK1',
#   'CKS1B',
#   'CKS2',
#   'COX5B',
#   'CRABP2',
#   'CSE1L',
#   'CSRP2',
#   'CTNNA1',
#   'DHX9',
#   'TIMM8A',
#   'DLAT',
#   'DNMT1',
#   'DTYMK',
#   'E2F3',
#   'ECHS1',
#   'PHC1',
#   'EEF2',
#   'EIF2S3',
#   'EIF4A1',
#   'EIF4B',
#   'EIF4EBP1',
#   'ENO1',
#   'FBL',
#   'ETFA',
#   'FARSA',
#   'FDPS',
#   'FGFR1',
#   'FH',
#   'GARS',
#   'GART',
#   'GJA1',
#   'GLDC',
#   'GLO1',
#   'HADH',
#   'HDAC1',
#   'HELLS',
#   'HMGB2',
#   'HNRNPA1',
#   'HNRPAB',
#   'HNRPK',
#   'HNRPL',
#   'PRMT1',
#   'HSPA9',
#   'HSPE1',
# ...

# %% [markdown]
# ###### sanchez-vega

# %% [markdown]
# pancan malignant pathway genes https://pubmed.ncbi.nlm.nih.gov/29625050/

# %%
gene_sets['sanchez-vega']
# Out:
# {'Cell Cycle': ['CDKN1A',
#   'CDKN1B',
#   'CDKN2A',
#   'CDKN2B',
#   'CDKN2C',
#   'CCND1',
#   'CCND2',
#   'CCND3',
#   'CCNE1',
#   'CDK2',
#   'CDK4',
#   'CDK6',
#   'RB1',
#   'E2F1',
#   'E2F3'],
#  'HIPPO': ['STK4',
#   'STK3',
#   'SAV1',
#   'LATS1',
#   'LATS2',
#   'MOB1A',
#   'MOB1B',
#   'YAP1',
#   'WWTR1',
#   'TEAD1',
#   'TEAD2',
#   'TEAD3',
#   'TEAD4',
#   'PTPN14',
#   'NF2',
#   'WWC1',
#   'TAOK1',
#   'TAOK2',
#   'TAOK3',
#   'CRB1',
#   'CRB2',
#   'CRB3',
#   'LLGL1',
#   'LLGL2',
#   'HMCN1',
#   'SCRIB',
#   'HIPK2',
#   'FAT1',
#   'FAT2',
#   'FAT3',
#   'FAT4',
#   'DCHS1',
#   'DCHS2',
#   'CSNK1E',
#   'CSNK1D',
#   'AJUBA',
#   'LIMD1',
#   'WTIP'],
#  'MYC': ['MAX',
#   'MGA',
#   'MLX',
#   'MLXIP',
#   'MLXIPL',
#   'MNT',
#   'MXD1',
#   'MXD3',
#   'MXD4',
#   'MXI1',
#   'MYC',
#   'MYCL',
#   'MYCN'],
#  'NOTCH': ['ARRDC1',
#   'CNTN6',
#   'CREBBP',
#   'EP300',
#   'HES1',
#   'HES2',
#   'HES3',
#   'HES4',
#   'HES5',
#   'HEY1',
# ...
