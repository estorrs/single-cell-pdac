# %%
import scanpy as sc
import pandas as pd
import numpy as np
import anndata

# %%
a = sc.read_h5ad('/diskmnt/Projects/Users/estorrs/pollock/b9fe457d-b933-466d-93aa-442c02ace2e3.h5ad')
a
# Out:
# AnnData object with n_obs × n_vars = 217292 × 36601
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'doublet_score', 'predicted_doublet', 'percent.mito', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.5', 'seurat_clusters', 'cell_type_individual', 'case_ID', 'sample_ID', 'piece_ID', 'cell_type_original_snRNA_merged_label_transfered', 'original_RNA_barcode', 'cell_type_merge', 'age', 'sex', 'race', 'ethnicity', 'primary_vs_met', 'treatment', 'organ', 'S.Score', 'G2M.Score', 'Phase', 'old.ident'
#     var: '_index', 'features'

# %%
a.raw

# %%
a.var_names_make_unique()
new = anndata.AnnData(X=a.raw.X, obs=a.obs)
new.var.index = a.raw.var.iloc[:, 0].to_list()
new.var.index = new.var.index.astype(str)
new.obs.index = new.obs.index.astype(str)
new.obs_names_make_unique()
new.var_names_make_unique()
new
# Out:
# /diskmnt/Projects/Users/estorrs/miniconda3/envs/single-cell-pdac/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
# AnnData object with n_obs × n_vars = 217292 × 36601
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'doublet_score', 'predicted_doublet', 'percent.mito', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.5', 'seurat_clusters', 'cell_type_individual', 'case_ID', 'sample_ID', 'piece_ID', 'cell_type_original_snRNA_merged_label_transfered', 'original_RNA_barcode', 'cell_type_merge', 'age', 'sex', 'race', 'ethnicity', 'primary_vs_met', 'treatment', 'organ', 'S.Score', 'G2M.Score', 'Phase', 'old.ident'

# %%
new.X
# Out:
# <217292x36601 sparse matrix of type '<class 'numpy.float32'>'
# 	with 407377599 stored elements in Compressed Sparse Row format>

# %%
new.obs
# Out:
#                                                                           orig.ident  \
# HT090P1-T2A3Y2N1Z1_1Bmn1_1_AAACAGCCAACCCTAA-1  HT090P1-T2A3Y2N1Z1_1Bmn1_1_snRNA-only
# HT090P1-T2A3Y2N1Z1_1Bmn1_1_AAACAGCCACGTAAGG-1  HT090P1-T2A3Y2N1Z1_1Bmn1_1_snRNA-only
# HT090P1-T2A3Y2N1Z1_1Bmn1_1_AAACATGCAAGTGAAC-1  HT090P1-T2A3Y2N1Z1_1Bmn1_1_snRNA-only
# HT090P1-T2A3Y2N1Z1_1Bmn1_1_AAACCAACAGTTTCTC-1  HT090P1-T2A3Y2N1Z1_1Bmn1_1_snRNA-only
# HT090P1-T2A3Y2N1Z1_1Bmn1_1_AAACCAACATTATGAC-1  HT090P1-T2A3Y2N1Z1_1Bmn1_1_snRNA-only
# ...                                                                              ...
# HT434P1-S1H1A3N1Z1_1Bmn1_1_TTTGTTGGTACTGATG-1             HT434P1-S1H1A3N1Z1_1Bmn1_1
# HT434P1-S1H1A3N1Z1_1Bmn1_1_TTTGTTGGTAGCCTAA-1             HT434P1-S1H1A3N1Z1_1Bmn1_1
# HT434P1-S1H1A3N1Z1_1Bmn1_1_TTTGTTGGTTAACAGT-1             HT434P1-S1H1A3N1Z1_1Bmn1_1
# HT434P1-S1H1A3N1Z1_1Bmn1_1_TTTGTTGGTTAAGGTT-1             HT434P1-S1H1A3N1Z1_1Bmn1_1
# ...

# %%
new.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [MIR1302-2HG, FAM138A, OR4F5, AL627309.1, AL627309.3, AL627309.2, AL627309.5, AL627309.4, AP006222.2, AL732372.1, OR4F29, AC114498.1, OR4F16, AL669831.2, LINC01409, FAM87B, LINC01128, LINC00115, FAM41C, AL645608.6, AL645608.2, AL645608.4, LINC02593, SAMD11, NOC2L, KLHL17, PLEKHN1, PERM1, AL645608.7, HES4, ISG15, AL645608.1, AGRN, AL645608.5, AL645608.8, RNF223, C1orf159, AL390719.3, LINC01342, AL390719.2, TTLL10-AS1, TTLL10, TNFRSF18, TNFRSF4, SDF4, B3GALT6, C1QTNF12, AL162741.1, UBE2J2, LINC01786, SCNN1D, ACAP3, PUSL1, INTS11, AL139287.1, CPTP, TAS1R3, DVL1, MXRA8, AURKAIP1, CCNL2, MRPL20-AS1, MRPL20, AL391244.2, ANKRD65, AL391244.1, TMEM88B, LINC01770, VWA1, ATAD3C, ATAD3B, ATAD3A, TMEM240, SSU72, AL645728.1, FNDC10, AL691432.4, AL691432.2, MIB2, MMP23B, CDK11B, FO704657.1, SLC35E2B, CDK11A, SLC35E2A, NADK, GNB1, AL109917.1, CALML6, TMEM52, CFAP74, AL391845.2, GABRD, AL391845.1, PRKCZ, AL590822.2, PRKCZ-AS1, FAAP20, AL590822.1, SKI, ...]
#
# ...
