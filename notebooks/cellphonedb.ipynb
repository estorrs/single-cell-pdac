# %%
import os

import pandas as pd
import numpy as np
import anndata
import scanpy as sc
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### input generation

# %%
sct = sc.read_h5ad('../data/single_cell/checkpoints/non_eus_processed.h5ad')
sct = sct[[True if 'Exclude' not in ct else False
          for ct in sct.obs['cell_type_specific_final']]]
f = anndata.AnnData(X=sct.X.toarray(),
                    obs=sct.obs[['cell_type_specific_final']],
                    var=sct.var)
f
# Out:
# AnnData object with n_obs × n_vars = 104486 × 29227
#     obs: 'cell_type_specific_final'

# %%
# save counts for cytotrace
df = pd.DataFrame(data=f.X, columns=f.var.index.to_list(),
                  index=f.obs.index.to_list())
df = df.transpose()
df['gene'] = [g.split('.')[0] for g in df.index.to_list()]
df = df.groupby('gene').mean()
df.index.name = 'Gene'
# make ids compatible with r
# df.columns = ['X' + c for c in df.columns]
# df.columns = [rify_cell_id(c) for c in df.columns]
# all members must be expressed in at least 10% of cells
# df = df[np.sum(df.values>0, axis=1)>=int(df.shape[1] * .1)]
df = df[np.sum(df.values>0, axis=1)>=0]
df
# Out:
#               1555-tumor_AAACCTGAGACCTAGG-1  1555-tumor_AAACCTGAGTGCGTGA-1  \
# Gene
# 7SK                                     0.0                            0.0
# A1BG                                    0.0                            0.0
# A1BG-AS1                                0.0                            0.0
# A1CF                                    0.0                            0.0
# A2M                                     0.0                            0.0
# ...                                     ...                            ...
# ZZZ3                                    0.0                            0.0
# bP-21264C1                              0.0                            0.0
# hsa-mir-1199                            0.0                            0.0
# hsa-mir-335                             0.0                            0.0
# hsa-mir-8072                            0.0                            0.0
#
#               1555-tumor_AAACCTGCATCCCACT-1  1555-tumor_AAACCTGGTCATGCAT-1  \
# Gene
# 7SK                                     0.0                            0.0
# A1BG                                    0.0                            0.0
# A1BG-AS1                                0.0                            0.0
# A1CF                                    0.0                            0.0
# A2M                                     0.0                            0.0
# ...                                     ...                            ...
# ZZZ3                                    0.0                            0.0
# bP-21264C1                              0.0                            0.0
# hsa-mir-1199                            0.0                            0.0
# hsa-mir-335                             0.0                            0.0
# hsa-mir-8072                            0.0                            0.0
#
#               1555-tumor_AAACCTGTCCGGGTGT-1  1555-tumor_AAACGGGAGACAATAC-1  \
# Gene
# 7SK                                     0.0                            0.0
# A1BG                                    0.0                            0.0
# A1BG-AS1                                0.0                            0.0
# A1CF                                    0.0                            0.0
# A2M                                     0.0                            0.0
# ...                                     ...                            ...
# ZZZ3                                    0.0                            0.0
# bP-21264C1                              0.0                            0.0
# hsa-mir-1199                            0.0                            0.0
# hsa-mir-335                             0.0                            0.0
# hsa-mir-8072                            0.0                            0.0
#
#               1555-tumor_AAACGGGAGGCGCTCT-1  1555-tumor_AAACGGGAGGGTATCG-1  \
# Gene
# 7SK                                     0.0                            0.0
# A1BG                                    0.0                            0.0
# A1BG-AS1                                0.0                            0.0
# A1CF                                    0.0                            0.0
# A2M                                     0.0                            0.0
# ...                                     ...                            ...
# ZZZ3                                    0.0                            0.0
# bP-21264C1                              0.0                            0.0
# hsa-mir-1199                            0.0                            0.0
# hsa-mir-335                             0.0                            0.0
# hsa-mir-8072                            0.0                            0.0
#
#               1555-tumor_AAACGGGGTGAGTGAC-1  1555-tumor_AAACGGGTCTCGCATC-1  \
# Gene
# 7SK                                0.000000                            0.0
# A1BG                               0.000000                            0.0
# A1BG-AS1                           0.000000                            0.0
# A1CF                               0.000000                            0.0
# A2M                                0.346574                            0.0
# ...                                     ...                            ...
# ZZZ3                               0.000000                            0.0
# bP-21264C1                         0.000000                            0.0
# hsa-mir-1199                       0.000000                            0.0
# hsa-mir-335                        0.000000                            0.0
# hsa-mir-8072                       0.000000                            0.0
#
#               ...  G9903_filtered_gene_bc_matrices_h5.h5_TTTGCGCCACAGGAGT-1  \
# Gene          ...
# 7SK           ...                                           0.549306
# A1BG          ...                                           0.000000
# A1BG-AS1      ...                                           0.000000
# A1CF          ...                                           0.000000
# A2M           ...                                           0.000000
# ...           ...                                                ...
# ZZZ3          ...                                           0.000000
# bP-21264C1    ...                                           0.000000
# hsa-mir-1199  ...                                           0.000000
# hsa-mir-335   ...                                           0.000000
# hsa-mir-8072  ...                                           0.000000
#
#               G9903_filtered_gene_bc_matrices_h5.h5_TTTGCGCGTACCGTAT-1  \
# Gene
# 7SK                                                    0.000000
# A1BG                                                   0.000000
# A1BG-AS1                                               0.000000
# A1CF                                                   0.000000
# A2M                                                    0.000000
# ...                                                         ...
# ZZZ3                                                   0.693147
# bP-21264C1                                             0.000000
# hsa-mir-1199                                           0.000000
# hsa-mir-335                                            0.000000
# hsa-mir-8072                                           0.000000
#
#               G9903_filtered_gene_bc_matrices_h5.h5_TTTGCGCGTGCAACTT-1  \
# Gene
# 7SK                                                     0.00000
# A1BG                                                    0.00000
# A1BG-AS1                                                0.00000
# A1CF                                                    0.00000
# A2M                                                     0.89588
# ...                                                         ...
# ZZZ3                                                    0.00000
# bP-21264C1                                              0.00000
# hsa-mir-1199                                            0.00000
# hsa-mir-335                                             0.00000
# hsa-mir-8072                                            0.00000
#
#               G9903_filtered_gene_bc_matrices_h5.h5_TTTGCGCTCGTGGACC-1  \
# Gene
# 7SK                                                         0.0
# A1BG                                                        0.0
# A1BG-AS1                                                    0.0
# A1CF                                                        0.0
# A2M                                                         0.0
# ...                                                         ...
# ZZZ3                                                        0.0
# bP-21264C1                                                  0.0
# hsa-mir-1199                                                0.0
# hsa-mir-335                                                 0.0
# hsa-mir-8072                                                0.0
#
#               G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTGTTGTACAC-1  \
# Gene
# 7SK                                                    0.000000
# A1BG                                                   0.000000
# A1BG-AS1                                               0.000000
# A1CF                                                   0.000000
# A2M                                                    0.000000
# ...                                                         ...
# ZZZ3                                                   0.693147
# bP-21264C1                                             0.000000
# hsa-mir-1199                                           0.000000
# hsa-mir-335                                            0.000000
# hsa-mir-8072                                           0.000000
#
#               G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTCCTAGTGA-1  \
# Gene
# 7SK                                                    0.000000
# A1BG                                                   0.346574
# A1BG-AS1                                               0.000000
# A1CF                                                   0.000000
# A2M                                                    0.000000
# ...                                                         ...
# ZZZ3                                                   0.000000
# bP-21264C1                                             0.000000
# hsa-mir-1199                                           0.000000
# hsa-mir-335                                            0.000000
# hsa-mir-8072                                           0.000000
#
#               G9903_filtered_gene_bc_matrices_h5.h5_TTTGGTTTCTACCAGA-1  \
# Gene
# 7SK                                                    0.000000
# A1BG                                                   0.346574
# A1BG-AS1                                               0.000000
# A1CF                                                   0.000000
# A2M                                                    0.000000
# ...                                                         ...
# ZZZ3                                                   0.000000
# bP-21264C1                                             0.000000
# hsa-mir-1199                                           0.000000
# hsa-mir-335                                            0.000000
# hsa-mir-8072                                           0.000000
#
#               G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCAAGTTGTCGT-1  \
# Gene
# 7SK                                                    0.000000
# A1BG                                                   0.346574
# A1BG-AS1                                               0.000000
# A1CF                                                   0.000000
# A2M                                                    0.000000
# ...                                                         ...
# ZZZ3                                                   0.000000
# bP-21264C1                                             0.000000
# hsa-mir-1199                                           0.000000
# hsa-mir-335                                            0.000000
# hsa-mir-8072                                           0.000000
#
#               G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCACAACTTGAC-1  \
# Gene
# 7SK                                                    0.000000
# A1BG                                                   0.346574
# A1BG-AS1                                               0.000000
# A1CF                                                   0.000000
# A2M                                                    0.000000
# ...                                                         ...
# ZZZ3                                                   0.000000
# bP-21264C1                                             0.000000
# hsa-mir-1199                                           0.000000
# hsa-mir-335                                            0.000000
# hsa-mir-8072                                           0.000000
#
#               G9903_filtered_gene_bc_matrices_h5.h5_TTTGTCATCCGAACGC-1
# Gene
# 7SK                                                         0.0
# A1BG                                                        0.0
# A1BG-AS1                                                    0.0
# A1CF                                                        0.0
# A2M                                                         0.0
# ...                                                         ...
# ZZZ3                                                        0.0
# bP-21264C1                                                  0.0
# hsa-mir-1199                                                0.0
# hsa-mir-335                                                 0.0
# hsa-mir-8072                                                0.0
#
# [26791 rows x 104486 columns]

# %%
# f.write_h5ad('../data/single_cell/cellphonedb/inputs/counts.h5ad')
df.to_csv('../data/single_cell/cellphonedb/inputs/counts.txt', sep='\t')

# %%
df = f.obs.copy()
df.index.name = 'Cell'
df.columns = ['cell_type']
df

# %%
df.to_csv('../data/single_cell/cellphonedb/inputs/meta.txt', sep='\t')

# %%
sc.tl.rank_genes_groups(sct, groupby='cell_type_specific_final')

# %%
sct.uns['rank_genes_groups']['names']

# %%
# top 100 for each
data = []
for ct in sorted(set(sct.obs['cell_type_specific_final'])):
    for gene in sct.uns['rank_genes_groups']['names'][ct][:100]:
        data.append([ct, gene])
df = pd.DataFrame(data=data, columns=['cluster', 'gene'])
df

# %%
df.to_csv('../data/single_cell/cellphonedb/inputs/degs.txt', sep='\t', index=False)

# %% [markdown]
# cellphonedb method degs_analysis test_meta.txt test_counts.txt test_DEGs.txt

# %% [markdown]
# cellphonedb method degs_analysis ~/Downloads/inputs/meta.txt ~/Downloads/inputs/counts.h5ad ~/Downloads/inputs/degs.txt --output-path ~/Downloads/cellphonedb_output

# %% [markdown]
# cellphonedb method degs_analysis  ~/Downloads/inputs/meta.txt  ~/Downloads/inputs/counts.txt --output-path ~/Downloads/cellphonedb_output ~/Downloads/inputs/degs.txt --subsampling --subsampling-log false --subsampling-num-cells 3000 --counts-data hgnc_symbol

# %% [markdown]
# cellphonedb method degs_analysis  ~/Downloads/inputs/meta.txt  ~/Downloads/inputs/counts.txt --output-path ~/Downloads/cellphonedb_output ~/Downloads/inputs/degs.txt --counts-data hgnc_symbol

# %% [markdown]
# #### visualization

# %%
means = pd.read_csv('../data/single_cell/cellphonedb/outputs/cellphonedb_output_full_ref/significant_means.txt',
                 sep='\t', index_col=0)
means
# Out:
#                        interacting_pair      partner_a             partner_b  \
# id_cp_interaction
# CPI-SS04C672963               ESAM_ESAM  simple:Q96AP7         simple:Q96AP7
# CPI-SS0B537DD3F         CEACAM5_CEACAM1  simple:P06731         simple:P13688
# CPI-SC04B0064C4    COL18A1_a2b1 complex  simple:P39060  complex:a2b1 complex
# CPI-SC0D9B795CC       CDH1_a2b1 complex  simple:P12830  complex:a2b1 complex
# CPI-SC035134F18     COL5A1_a2b1 complex  simple:P20908  complex:a2b1 complex
# ...                                 ...            ...                   ...
# CPI-SC01E9FAC20    COL16A1_a2b1 complex  simple:Q07092  complex:a2b1 complex
# CPI-SS01A07768A               CD46_JAG1  simple:P15529         simple:P78504
# CPI-SC06873D10F    COL17A1_a2b1 complex  simple:Q9UMD9  complex:a2b1 complex
# CPI-SS04F3A1E5C              COPA_SORT1  simple:P53621         simple:Q99523
# CPI-SS0BC7CD11B              LGALS9_MET  simple:O00182         simple:P08581
#
#                     gene_a   gene_b  secreted  receptor_a  receptor_b  \
# id_cp_interaction
# CPI-SS04C672963       ESAM     ESAM     False       False       False
# CPI-SS0B537DD3F    CEACAM5  CEACAM1      True       False       False
# CPI-SC04B0064C4    COL18A1      NaN      True       False       False
# CPI-SC0D9B795CC       CDH1      NaN     False       False       False
# CPI-SC035134F18     COL5A1      NaN      True       False       False
# ...                    ...      ...       ...         ...         ...
# CPI-SC01E9FAC20    COL16A1      NaN      True       False       False
# CPI-SS01A07768A       CD46     JAG1     False        True       False
# CPI-SC06873D10F    COL17A1      NaN      True       False       False
# CPI-SS04F3A1E5C       COPA    SORT1      True       False        True
# CPI-SS0BC7CD11B     LGALS9      MET      True       False        True
#
#                                  annotation_strategy  is_integrin  ...  \
# id_cp_interaction                                                  ...
# CPI-SS04C672963                              curated        False  ...
# CPI-SS0B537DD3F                              curated        False  ...
# CPI-SC04B0064C4                              curated         True  ...
# CPI-SC0D9B795CC                              curated         True  ...
# CPI-SC035134F18                              curated         True  ...
# ...                                              ...          ...  ...
# CPI-SC01E9FAC20                              curated         True  ...
# CPI-SS01A07768A                              curated        False  ...
# CPI-SC06873D10F                              curated         True  ...
# CPI-SS04F3A1E5C    IMEx,InnateDB-All,IntAct,MatrixDB        False  ...
# CPI-SS0BC7CD11B                         InnateDB-All        False  ...
#
#                    myCAF|NK  myCAF|Plasma  myCAF|Stellate  myCAF|TAM - C1QC  \
# id_cp_interaction
# CPI-SS04C672963         NaN           NaN             NaN               NaN
# CPI-SS0B537DD3F         NaN           NaN             NaN               NaN
# CPI-SC04B0064C4         NaN           NaN             NaN               NaN
# CPI-SC0D9B795CC         NaN           NaN             NaN               NaN
# CPI-SC035134F18         NaN           NaN             NaN               NaN
# ...                     ...           ...             ...               ...
# CPI-SC01E9FAC20         NaN           NaN             NaN               NaN
# CPI-SS01A07768A         NaN           NaN             NaN               NaN
# CPI-SC06873D10F         NaN           NaN             NaN               NaN
# CPI-SS04F3A1E5C         NaN           NaN             NaN               NaN
# CPI-SS0BC7CD11B         NaN           NaN             NaN               NaN
#
#                    myCAF|TAM - FCN1  myCAF|TAM - Proliferating  \
# id_cp_interaction
# CPI-SS04C672963                 NaN                        NaN
# CPI-SS0B537DD3F                 NaN                        NaN
# CPI-SC04B0064C4                 NaN                        NaN
# CPI-SC0D9B795CC                 NaN                        NaN
# CPI-SC035134F18                 NaN                        NaN
# ...                             ...                        ...
# CPI-SC01E9FAC20                 NaN                        NaN
# CPI-SS01A07768A                 NaN                        NaN
# CPI-SC06873D10F                 NaN                        NaN
# CPI-SS04F3A1E5C                 NaN                        NaN
# CPI-SS0BC7CD11B                 NaN                        NaN
#
#                    myCAF|TAM - SPP1  myCAF|Treg  myCAF|iCAF  myCAF|myCAF
# id_cp_interaction
# CPI-SS04C672963                 NaN         NaN         NaN          NaN
# CPI-SS0B537DD3F                 NaN         NaN         NaN          NaN
# CPI-SC04B0064C4                 NaN         NaN         NaN          NaN
# CPI-SC0D9B795CC                 NaN         NaN         NaN          NaN
# CPI-SC035134F18                 NaN         NaN         NaN          NaN
# ...                             ...         ...         ...          ...
# CPI-SC01E9FAC20                 NaN         NaN         NaN          NaN
# CPI-SS01A07768A                 NaN         NaN         NaN          NaN
# CPI-SC06873D10F                 NaN         NaN         NaN          NaN
# CPI-SS04F3A1E5C                 NaN         NaN         NaN          NaN
# CPI-SS0BC7CD11B                 NaN         NaN         NaN          NaN
#
# [102 rows x 740 columns]

# %%
interactions = pd.read_csv('../data/single_cell/cellphonedb/outputs/cellphonedb_output_full_ref/relevant_interactions.txt',
                          sep='\t', index_col=0)
interactions
# Out:
#                       interacting_pair      partner_a             partner_b  \
# id_cp_interaction
# CPI-SC0F73E9099    COL1A1_a1b1 complex  simple:P02452  complex:a1b1 complex
# CPI-SC0BC63F8C0    COL3A1_a1b1 complex  simple:P02461  complex:a1b1 complex
# CPI-SC0672FBD31    COL4A1_a1b1 complex  simple:P02462  complex:a1b1 complex
# CPI-SC0545E2502    COL5A2_a1b1 complex  simple:P05997  complex:a1b1 complex
# CPI-SC006E22794    COL1A2_a1b1 complex  simple:P08123  complex:a1b1 complex
# ...                                ...            ...                   ...
# CPI-SS0B537DD3F        CEACAM5_CEACAM1  simple:P06731         simple:P13688
# CPI-SS080611C5B          ALOX5_ALOX5AP  simple:P09917         simple:P20292
# CPI-SS06CBC985C               LTBR_LTB  simple:P36941         simple:Q06643
# CPI-SS06D13FCD3              DSC2_DSG2  simple:Q02487         simple:Q14126
# CPI-SS04C672963              ESAM_ESAM  simple:Q96AP7         simple:Q96AP7
#
#                     gene_a   gene_b  secreted  receptor_a  receptor_b  \
# id_cp_interaction
# CPI-SC0F73E9099     COL1A1      NaN      True       False       False
# CPI-SC0BC63F8C0     COL3A1      NaN      True       False       False
# CPI-SC0672FBD31     COL4A1      NaN      True       False       False
# CPI-SC0545E2502     COL5A2      NaN      True       False       False
# CPI-SC006E22794     COL1A2      NaN      True       False       False
# ...                    ...      ...       ...         ...         ...
# CPI-SS0B537DD3F    CEACAM5  CEACAM1      True       False       False
# CPI-SS080611C5B      ALOX5  ALOX5AP     False       False       False
# CPI-SS06CBC985C       LTBR      LTB     False        True       False
# CPI-SS06D13FCD3       DSC2     DSG2     False       False       False
# CPI-SS04C672963       ESAM     ESAM     False       False       False
#
#                        annotation_strategy  is_integrin  ...  myCAF|Mast  \
# id_cp_interaction                                        ...
# CPI-SC0F73E9099                    curated         True  ...           0
# CPI-SC0BC63F8C0                    curated         True  ...           0
# CPI-SC0672FBD31                    curated         True  ...           0
# CPI-SC0545E2502                    curated         True  ...           0
# CPI-SC006E22794                    curated         True  ...           0
# ...                                    ...          ...  ...         ...
# CPI-SS0B537DD3F                    curated        False  ...           0
# CPI-SS080611C5B    guidetopharmacology.org        False  ...           0
# CPI-SS06CBC985C                    curated        False  ...           0
# CPI-SS06D13FCD3                    curated        False  ...           0
# CPI-SS04C672963                    curated        False  ...           0
#
#                    myCAF|NK  myCAF|Stellate  myCAF|TAM - C1QC  \
# id_cp_interaction
# CPI-SC0F73E9099           1               1                 0
# CPI-SC0BC63F8C0           1               1                 0
# CPI-SC0672FBD31           0               1                 0
# CPI-SC0545E2502           1               1                 0
# CPI-SC006E22794           1               1                 0
# ...                     ...             ...               ...
# CPI-SS0B537DD3F           0               0                 0
# CPI-SS080611C5B           0               0                 0
# CPI-SS06CBC985C           0               0                 0
# CPI-SS06D13FCD3           0               0                 0
# CPI-SS04C672963           0               0                 0
#
#                    myCAF|TAM - FCN1  myCAF|TAM - Proliferating  \
# id_cp_interaction
# CPI-SC0F73E9099                   0                          0
# CPI-SC0BC63F8C0                   0                          0
# CPI-SC0672FBD31                   0                          0
# CPI-SC0545E2502                   0                          0
# CPI-SC006E22794                   0                          0
# ...                             ...                        ...
# CPI-SS0B537DD3F                   0                          0
# CPI-SS080611C5B                   0                          0
# CPI-SS06CBC985C                   0                          0
# CPI-SS06D13FCD3                   0                          0
# CPI-SS04C672963                   0                          0
#
#                    myCAF|TAM - SPP1  myCAF|Treg  myCAF|iCAF  myCAF|myCAF
# id_cp_interaction
# CPI-SC0F73E9099                   0           0           1            1
# CPI-SC0BC63F8C0                   0           0           1            1
# CPI-SC0672FBD31                   0           0           0            1
# CPI-SC0545E2502                   0           0           1            1
# CPI-SC006E22794                   0           0           1            1
# ...                             ...         ...         ...          ...
# CPI-SS0B537DD3F                   0           0           0            0
# CPI-SS080611C5B                   0           0           0            0
# CPI-SS06CBC985C                   0           1           0            0
# CPI-SS06D13FCD3                   0           0           0            0
# CPI-SS04C672963                   0           0           0            0
#
# [70 rows x 656 columns]

# %%
list(means.columns)
# Out:
# ['interacting_pair',
#  'partner_a',
#  'partner_b',
#  'gene_a',
#  'gene_b',
#  'secreted',
#  'receptor_a',
#  'receptor_b',
#  'annotation_strategy',
#  'is_integrin',
#  'rank',
#  'ADM|ADM',
#  'ADM|Acinar',
#  'ADM|B cell',
#  'ADM|CD4 T cell',
#  'ADM|CD8 T cell',
#  'ADM|CD8 T cell - Exhausted',
#  'ADM|DC',
#  'ADM|Endocrine',
#  'ADM|Endothelial',
#  'ADM|Immune - Proliferating',
#  'ADM|Malignant - Basal',
#  'ADM|Malignant - Classical',
#  'ADM|Malignant - IC',
#  'ADM|Malignant - Proliferating Basal',
#  'ADM|Malignant - Proliferating Classical',
#  'ADM|Malignant - Proliferating IC',
#  'ADM|Mast',
#  'ADM|NK',
#  'ADM|Plasma',
#  'ADM|Stellate',
#  'ADM|TAM - C1QC',
#  'ADM|TAM - FCN1',
#  'ADM|TAM - Proliferating',
#  'ADM|TAM - SPP1',
#  'ADM|Treg',
#  'ADM|iCAF',
#  'ADM|myCAF',
#  'Acinar|ADM',
#  'Acinar|Acinar',
#  'Acinar|B cell',
#  'Acinar|CD4 T cell',
#  'Acinar|CD8 T cell',
#  'Acinar|CD8 T cell - Exhausted',
#  'Acinar|DC',
#  'Acinar|Endocrine',
#  'Acinar|Endothelial',
#  'Acinar|Immune - Proliferating',
#  'Acinar|Malignant - Basal',
#  'Acinar|Malignant - Classical',
#  'Acinar|Malignant - IC',
#  'Acinar|Malignant - Proliferating Basal',
#  'Acinar|Malignant - Proliferating Classical',
#  'Acinar|Malignant - Proliferating IC',
#  'Acinar|Mast',
#  'Acinar|NK',
#  'Acinar|Plasma',
#  'Acinar|Stellate',
#  'Acinar|TAM - C1QC',
#  'Acinar|TAM - FCN1',
#  'Acinar|TAM - Proliferating',
#  'Acinar|TAM - SPP1',
#  'Acinar|Treg',
#  'Acinar|iCAF',
#  'Acinar|myCAF',
#  'B cell|ADM',
#  'B cell|Acinar',
#  'B cell|B cell',
#  'B cell|CD4 T cell',
#  'B cell|CD8 T cell',
#  'B cell|CD8 T cell - Exhausted',
#  'B cell|DC',
#  'B cell|Endocrine',
#  'B cell|Endothelial',
#  'B cell|Immune - Proliferating',
#  'B cell|Malignant - Basal',
#  'B cell|Malignant - Classical',
#  'B cell|Malignant - IC',
#  'B cell|Malignant - Proliferating Basal',
#  'B cell|Malignant - Proliferating Classical',
#  'B cell|Malignant - Proliferating IC',
#  'B cell|Mast',
#  'B cell|NK',
#  'B cell|Plasma',
#  'B cell|Stellate',
#  'B cell|TAM - C1QC',
#  'B cell|TAM - FCN1',
#  'B cell|TAM - Proliferating',
#  'B cell|TAM - SPP1',
#  'B cell|Treg',
#  'B cell|iCAF',
#  'B cell|myCAF',
#  'CD4 T cell|ADM',
#  'CD4 T cell|Acinar',
#  'CD4 T cell|B cell',
#  'CD4 T cell|CD4 T cell',
#  'CD4 T cell|CD8 T cell',
#  'CD4 T cell|CD8 T cell - Exhausted',
#  'CD4 T cell|DC',
#  'CD4 T cell|Endocrine',
#  'CD4 T cell|Endothelial',
#  'CD4 T cell|Immune - Proliferating',
#  'CD4 T cell|Malignant - Basal',
#  'CD4 T cell|Malignant - Classical',
#  'CD4 T cell|Malignant - IC',
#  'CD4 T cell|Malignant - Proliferating Basal',
#  'CD4 T cell|Malignant - Proliferating Classical',
#  'CD4 T cell|Malignant - Proliferating IC',
#  'CD4 T cell|Mast',
#  'CD4 T cell|NK',
#  'CD4 T cell|Plasma',
#  'CD4 T cell|Stellate',
#  'CD4 T cell|TAM - C1QC',
#  'CD4 T cell|TAM - FCN1',
#  'CD4 T cell|TAM - Proliferating',
#  'CD4 T cell|TAM - SPP1',
#  'CD4 T cell|Treg',
#  'CD4 T cell|iCAF',
#  'CD4 T cell|myCAF',
#  'CD8 T cell|ADM',
#  'CD8 T cell|Acinar',
#  'CD8 T cell|B cell',
#  'CD8 T cell|CD4 T cell',
#  'CD8 T cell|CD8 T cell',
#  'CD8 T cell|CD8 T cell - Exhausted',
#  'CD8 T cell|DC',
#  'CD8 T cell|Endocrine',
#  'CD8 T cell|Endothelial',
#  'CD8 T cell|Immune - Proliferating',
#  'CD8 T cell|Malignant - Basal',
#  'CD8 T cell|Malignant - Classical',
#  'CD8 T cell|Malignant - IC',
#  'CD8 T cell|Malignant - Proliferating Basal',
#  'CD8 T cell|Malignant - Proliferating Classical',
#  'CD8 T cell|Malignant - Proliferating IC',
#  'CD8 T cell|Mast',
#  'CD8 T cell|NK',
#  'CD8 T cell|Plasma',
#  'CD8 T cell|Stellate',
#  'CD8 T cell|TAM - C1QC',
#  'CD8 T cell|TAM - FCN1',
#  'CD8 T cell|TAM - Proliferating',
#  'CD8 T cell|TAM - SPP1',
#  'CD8 T cell|Treg',
#  'CD8 T cell|iCAF',
#  'CD8 T cell|myCAF',
#  'CD8 T cell - Exhausted|ADM',
#  'CD8 T cell - Exhausted|Acinar',
#  'CD8 T cell - Exhausted|B cell',
#  'CD8 T cell - Exhausted|CD4 T cell',
#  'CD8 T cell - Exhausted|CD8 T cell',
#  'CD8 T cell - Exhausted|CD8 T cell - Exhausted',
#  'CD8 T cell - Exhausted|DC',
#  'CD8 T cell - Exhausted|Endocrine',
#  'CD8 T cell - Exhausted|Endothelial',
#  'CD8 T cell - Exhausted|Immune - Proliferating',
#  'CD8 T cell - Exhausted|Malignant - Basal',
#  'CD8 T cell - Exhausted|Malignant - Classical',
#  'CD8 T cell - Exhausted|Malignant - IC',
#  'CD8 T cell - Exhausted|Malignant - Proliferating Basal',
#  'CD8 T cell - Exhausted|Malignant - Proliferating Classical',
#  'CD8 T cell - Exhausted|Malignant - Proliferating IC',
#  'CD8 T cell - Exhausted|Mast',
#  'CD8 T cell - Exhausted|NK',
#  'CD8 T cell - Exhausted|Plasma',
#  'CD8 T cell - Exhausted|Stellate',
#  'CD8 T cell - Exhausted|TAM - C1QC',
#  'CD8 T cell - Exhausted|TAM - FCN1',
#  'CD8 T cell - Exhausted|TAM - Proliferating',
#  'CD8 T cell - Exhausted|TAM - SPP1',
#  'CD8 T cell - Exhausted|Treg',
#  'CD8 T cell - Exhausted|iCAF',
#  'CD8 T cell - Exhausted|myCAF',
#  'DC|ADM',
#  'DC|Acinar',
#  'DC|B cell',
#  'DC|CD4 T cell',
#  'DC|CD8 T cell',
#  'DC|CD8 T cell - Exhausted',
#  'DC|DC',
#  'DC|Endocrine',
#  'DC|Endothelial',
#  'DC|Immune - Proliferating',
#  'DC|Malignant - Basal',
#  'DC|Malignant - Classical',
#  'DC|Malignant - IC',
#  'DC|Malignant - Proliferating Basal',
#  'DC|Malignant - Proliferating Classical',
#  'DC|Malignant - Proliferating IC',
#  'DC|Mast',
#  'DC|NK',
#  'DC|Plasma',
#  'DC|Stellate',
#  'DC|TAM - C1QC',
#  'DC|TAM - FCN1',
#  'DC|TAM - Proliferating',
#  'DC|TAM - SPP1',
#  'DC|Treg',
#  'DC|iCAF',
#  'DC|myCAF',
#  'Endocrine|ADM',
#  'Endocrine|Acinar',
#  'Endocrine|B cell',
#  'Endocrine|CD4 T cell',
#  'Endocrine|CD8 T cell',
#  'Endocrine|CD8 T cell - Exhausted',
#  'Endocrine|DC',
#  'Endocrine|Endocrine',
#  'Endocrine|Endothelial',
#  'Endocrine|Immune - Proliferating',
#  'Endocrine|Malignant - Basal',
#  'Endocrine|Malignant - Classical',
#  'Endocrine|Malignant - IC',
#  'Endocrine|Malignant - Proliferating Basal',
#  'Endocrine|Malignant - Proliferating Classical',
#  'Endocrine|Malignant - Proliferating IC',
#  'Endocrine|Mast',
#  'Endocrine|NK',
#  'Endocrine|Plasma',
#  'Endocrine|Stellate',
#  'Endocrine|TAM - C1QC',
#  'Endocrine|TAM - FCN1',
#  'Endocrine|TAM - Proliferating',
#  'Endocrine|TAM - SPP1',
#  'Endocrine|Treg',
#  'Endocrine|iCAF',
#  'Endocrine|myCAF',
#  'Endothelial|ADM',
#  'Endothelial|Acinar',
#  'Endothelial|B cell',
#  'Endothelial|CD4 T cell',
#  'Endothelial|CD8 T cell',
#  'Endothelial|CD8 T cell - Exhausted',
#  'Endothelial|DC',
#  'Endothelial|Endocrine',
#  'Endothelial|Endothelial',
#  'Endothelial|Immune - Proliferating',
#  'Endothelial|Malignant - Basal',
#  'Endothelial|Malignant - Classical',
#  'Endothelial|Malignant - IC',
#  'Endothelial|Malignant - Proliferating Basal',
#  'Endothelial|Malignant - Proliferating Classical',
#  'Endothelial|Malignant - Proliferating IC',
#  'Endothelial|Mast',
#  'Endothelial|NK',
#  'Endothelial|Plasma',
#  'Endothelial|Stellate',
#  'Endothelial|TAM - C1QC',
#  'Endothelial|TAM - FCN1',
#  'Endothelial|TAM - Proliferating',
#  'Endothelial|TAM - SPP1',
#  'Endothelial|Treg',
#  'Endothelial|iCAF',
#  'Endothelial|myCAF',
#  'Immune - Proliferating|ADM',
#  'Immune - Proliferating|Acinar',
#  'Immune - Proliferating|B cell',
#  'Immune - Proliferating|CD4 T cell',
#  'Immune - Proliferating|CD8 T cell',
#  'Immune - Proliferating|CD8 T cell - Exhausted',
#  'Immune - Proliferating|DC',
#  'Immune - Proliferating|Endocrine',
#  'Immune - Proliferating|Endothelial',
#  'Immune - Proliferating|Immune - Proliferating',
#  'Immune - Proliferating|Malignant - Basal',
#  'Immune - Proliferating|Malignant - Classical',
#  'Immune - Proliferating|Malignant - IC',
#  'Immune - Proliferating|Malignant - Proliferating Basal',
#  'Immune - Proliferating|Malignant - Proliferating Classical',
#  'Immune - Proliferating|Malignant - Proliferating IC',
#  'Immune - Proliferating|Mast',
#  'Immune - Proliferating|NK',
#  'Immune - Proliferating|Plasma',
#  'Immune - Proliferating|Stellate',
#  'Immune - Proliferating|TAM - C1QC',
#  'Immune - Proliferating|TAM - FCN1',
#  'Immune - Proliferating|TAM - Proliferating',
#  'Immune - Proliferating|TAM - SPP1',
#  'Immune - Proliferating|Treg',
#  'Immune - Proliferating|iCAF',
#  'Immune - Proliferating|myCAF',
#  'Malignant - Basal|ADM',
#  'Malignant - Basal|Acinar',
#  'Malignant - Basal|B cell',
#  'Malignant - Basal|CD4 T cell',
#  'Malignant - Basal|CD8 T cell',
#  'Malignant - Basal|CD8 T cell - Exhausted',
#  'Malignant - Basal|DC',
#  'Malignant - Basal|Endocrine',
#  'Malignant - Basal|Endothelial',
#  'Malignant - Basal|Immune - Proliferating',
#  'Malignant - Basal|Malignant - Basal',
#  'Malignant - Basal|Malignant - Classical',
#  'Malignant - Basal|Malignant - IC',
#  'Malignant - Basal|Malignant - Proliferating Basal',
#  'Malignant - Basal|Malignant - Proliferating Classical',
#  'Malignant - Basal|Malignant - Proliferating IC',
#  'Malignant - Basal|Mast',
#  'Malignant - Basal|NK',
#  'Malignant - Basal|Plasma',
#  'Malignant - Basal|Stellate',
#  'Malignant - Basal|TAM - C1QC',
#  'Malignant - Basal|TAM - FCN1',
#  'Malignant - Basal|TAM - Proliferating',
#  'Malignant - Basal|TAM - SPP1',
#  'Malignant - Basal|Treg',
#  'Malignant - Basal|iCAF',
#  'Malignant - Basal|myCAF',
#  'Malignant - Classical|ADM',
#  'Malignant - Classical|Acinar',
#  'Malignant - Classical|B cell',
#  'Malignant - Classical|CD4 T cell',
#  'Malignant - Classical|CD8 T cell',
#  'Malignant - Classical|CD8 T cell - Exhausted',
#  'Malignant - Classical|DC',
#  'Malignant - Classical|Endocrine',
#  'Malignant - Classical|Endothelial',
#  'Malignant - Classical|Immune - Proliferating',
#  'Malignant - Classical|Malignant - Basal',
#  'Malignant - Classical|Malignant - Classical',
#  'Malignant - Classical|Malignant - IC',
#  'Malignant - Classical|Malignant - Proliferating Basal',
#  'Malignant - Classical|Malignant - Proliferating Classical',
#  'Malignant - Classical|Malignant - Proliferating IC',
#  'Malignant - Classical|Mast',
#  'Malignant - Classical|NK',
#  'Malignant - Classical|Plasma',
#  'Malignant - Classical|Stellate',
#  'Malignant - Classical|TAM - C1QC',
#  'Malignant - Classical|TAM - FCN1',
#  'Malignant - Classical|TAM - Proliferating',
#  'Malignant - Classical|TAM - SPP1',
#  'Malignant - Classical|Treg',
#  'Malignant - Classical|iCAF',
#  'Malignant - Classical|myCAF',
#  'Malignant - IC|ADM',
#  'Malignant - IC|Acinar',
#  'Malignant - IC|B cell',
#  'Malignant - IC|CD4 T cell',
#  'Malignant - IC|CD8 T cell',
#  'Malignant - IC|CD8 T cell - Exhausted',
#  'Malignant - IC|DC',
#  'Malignant - IC|Endocrine',
#  'Malignant - IC|Endothelial',
#  'Malignant - IC|Immune - Proliferating',
#  'Malignant - IC|Malignant - Basal',
#  'Malignant - IC|Malignant - Classical',
#  'Malignant - IC|Malignant - IC',
#  'Malignant - IC|Malignant - Proliferating Basal',
#  'Malignant - IC|Malignant - Proliferating Classical',
#  'Malignant - IC|Malignant - Proliferating IC',
#  'Malignant - IC|Mast',
#  'Malignant - IC|NK',
#  'Malignant - IC|Plasma',
#  'Malignant - IC|Stellate',
#  'Malignant - IC|TAM - C1QC',
#  'Malignant - IC|TAM - FCN1',
#  'Malignant - IC|TAM - Proliferating',
#  'Malignant - IC|TAM - SPP1',
#  'Malignant - IC|Treg',
#  'Malignant - IC|iCAF',
#  'Malignant - IC|myCAF',
#  'Malignant - Proliferating Basal|ADM',
#  'Malignant - Proliferating Basal|Acinar',
#  'Malignant - Proliferating Basal|B cell',
#  'Malignant - Proliferating Basal|CD4 T cell',
#  'Malignant - Proliferating Basal|CD8 T cell',
#  'Malignant - Proliferating Basal|CD8 T cell - Exhausted',
#  'Malignant - Proliferating Basal|DC',
#  'Malignant - Proliferating Basal|Endocrine',
#  'Malignant - Proliferating Basal|Endothelial',
#  'Malignant - Proliferating Basal|Immune - Proliferating',
#  'Malignant - Proliferating Basal|Malignant - Basal',
#  'Malignant - Proliferating Basal|Malignant - Classical',
#  'Malignant - Proliferating Basal|Malignant - IC',
#  'Malignant - Proliferating Basal|Malignant - Proliferating Basal',
#  'Malignant - Proliferating Basal|Malignant - Proliferating Classical',
#  'Malignant - Proliferating Basal|Malignant - Proliferating IC',
#  'Malignant - Proliferating Basal|Mast',
#  'Malignant - Proliferating Basal|NK',
#  'Malignant - Proliferating Basal|Plasma',
#  'Malignant - Proliferating Basal|Stellate',
#  'Malignant - Proliferating Basal|TAM - C1QC',
#  'Malignant - Proliferating Basal|TAM - FCN1',
#  'Malignant - Proliferating Basal|TAM - Proliferating',
#  'Malignant - Proliferating Basal|TAM - SPP1',
#  'Malignant - Proliferating Basal|Treg',
#  'Malignant - Proliferating Basal|iCAF',
#  'Malignant - Proliferating Basal|myCAF',
#  'Malignant - Proliferating Classical|ADM',
#  'Malignant - Proliferating Classical|Acinar',
#  'Malignant - Proliferating Classical|B cell',
#  'Malignant - Proliferating Classical|CD4 T cell',
#  'Malignant - Proliferating Classical|CD8 T cell',
#  'Malignant - Proliferating Classical|CD8 T cell - Exhausted',
#  'Malignant - Proliferating Classical|DC',
#  'Malignant - Proliferating Classical|Endocrine',
#  'Malignant - Proliferating Classical|Endothelial',
#  'Malignant - Proliferating Classical|Immune - Proliferating',
#  'Malignant - Proliferating Classical|Malignant - Basal',
#  'Malignant - Proliferating Classical|Malignant - Classical',
#  'Malignant - Proliferating Classical|Malignant - IC',
#  'Malignant - Proliferating Classical|Malignant - Proliferating Basal',
#  'Malignant - Proliferating Classical|Malignant - Proliferating Classical',
#  'Malignant - Proliferating Classical|Malignant - Proliferating IC',
#  'Malignant - Proliferating Classical|Mast',
#  'Malignant - Proliferating Classical|NK',
#  'Malignant - Proliferating Classical|Plasma',
#  'Malignant - Proliferating Classical|Stellate',
#  'Malignant - Proliferating Classical|TAM - C1QC',
#  'Malignant - Proliferating Classical|TAM - FCN1',
#  'Malignant - Proliferating Classical|TAM - Proliferating',
#  'Malignant - Proliferating Classical|TAM - SPP1',
#  'Malignant - Proliferating Classical|Treg',
#  'Malignant - Proliferating Classical|iCAF',
#  'Malignant - Proliferating Classical|myCAF',
#  'Malignant - Proliferating IC|ADM',
#  'Malignant - Proliferating IC|Acinar',
#  'Malignant - Proliferating IC|B cell',
#  'Malignant - Proliferating IC|CD4 T cell',
#  'Malignant - Proliferating IC|CD8 T cell',
#  'Malignant - Proliferating IC|CD8 T cell - Exhausted',
#  'Malignant - Proliferating IC|DC',
#  'Malignant - Proliferating IC|Endocrine',
#  'Malignant - Proliferating IC|Endothelial',
#  'Malignant - Proliferating IC|Immune - Proliferating',
#  'Malignant - Proliferating IC|Malignant - Basal',
#  'Malignant - Proliferating IC|Malignant - Classical',
#  'Malignant - Proliferating IC|Malignant - IC',
#  'Malignant - Proliferating IC|Malignant - Proliferating Basal',
#  'Malignant - Proliferating IC|Malignant - Proliferating Classical',
#  'Malignant - Proliferating IC|Malignant - Proliferating IC',
#  'Malignant - Proliferating IC|Mast',
#  'Malignant - Proliferating IC|NK',
#  'Malignant - Proliferating IC|Plasma',
#  'Malignant - Proliferating IC|Stellate',
#  'Malignant - Proliferating IC|TAM - C1QC',
#  'Malignant - Proliferating IC|TAM - FCN1',
#  'Malignant - Proliferating IC|TAM - Proliferating',
#  'Malignant - Proliferating IC|TAM - SPP1',
#  'Malignant - Proliferating IC|Treg',
#  'Malignant - Proliferating IC|iCAF',
#  'Malignant - Proliferating IC|myCAF',
#  'Mast|ADM',
#  'Mast|Acinar',
#  'Mast|B cell',
#  'Mast|CD4 T cell',
#  'Mast|CD8 T cell',
#  'Mast|CD8 T cell - Exhausted',
#  'Mast|DC',
#  'Mast|Endocrine',
#  'Mast|Endothelial',
#  'Mast|Immune - Proliferating',
#  'Mast|Malignant - Basal',
#  'Mast|Malignant - Classical',
#  'Mast|Malignant - IC',
#  'Mast|Malignant - Proliferating Basal',
#  'Mast|Malignant - Proliferating Classical',
#  'Mast|Malignant - Proliferating IC',
#  'Mast|Mast',
#  'Mast|NK',
#  'Mast|Plasma',
#  'Mast|Stellate',
#  'Mast|TAM - C1QC',
#  'Mast|TAM - FCN1',
#  'Mast|TAM - Proliferating',
#  'Mast|TAM - SPP1',
#  'Mast|Treg',
#  'Mast|iCAF',
#  'Mast|myCAF',
#  'NK|ADM',
#  'NK|Acinar',
#  'NK|B cell',
#  'NK|CD4 T cell',
#  'NK|CD8 T cell',
#  'NK|CD8 T cell - Exhausted',
#  'NK|DC',
#  'NK|Endocrine',
#  'NK|Endothelial',
#  'NK|Immune - Proliferating',
#  'NK|Malignant - Basal',
#  'NK|Malignant - Classical',
#  'NK|Malignant - IC',
#  'NK|Malignant - Proliferating Basal',
#  'NK|Malignant - Proliferating Classical',
#  'NK|Malignant - Proliferating IC',
#  'NK|Mast',
#  'NK|NK',
#  'NK|Plasma',
#  'NK|Stellate',
#  'NK|TAM - C1QC',
#  'NK|TAM - FCN1',
#  'NK|TAM - Proliferating',
#  'NK|TAM - SPP1',
#  'NK|Treg',
#  'NK|iCAF',
#  'NK|myCAF',
#  'Plasma|ADM',
#  'Plasma|Acinar',
#  'Plasma|B cell',
#  'Plasma|CD4 T cell',
#  'Plasma|CD8 T cell',
#  'Plasma|CD8 T cell - Exhausted',
#  'Plasma|DC',
#  'Plasma|Endocrine',
#  'Plasma|Endothelial',
#  'Plasma|Immune - Proliferating',
#  'Plasma|Malignant - Basal',
#  'Plasma|Malignant - Classical',
#  'Plasma|Malignant - IC',
#  'Plasma|Malignant - Proliferating Basal',
#  'Plasma|Malignant - Proliferating Classical',
#  'Plasma|Malignant - Proliferating IC',
#  'Plasma|Mast',
#  'Plasma|NK',
#  'Plasma|Plasma',
#  'Plasma|Stellate',
#  'Plasma|TAM - C1QC',
#  'Plasma|TAM - FCN1',
#  'Plasma|TAM - Proliferating',
#  'Plasma|TAM - SPP1',
#  'Plasma|Treg',
#  'Plasma|iCAF',
#  'Plasma|myCAF',
#  'Stellate|ADM',
#  'Stellate|Acinar',
#  'Stellate|B cell',
#  'Stellate|CD4 T cell',
#  'Stellate|CD8 T cell',
#  'Stellate|CD8 T cell - Exhausted',
#  'Stellate|DC',
#  'Stellate|Endocrine',
#  'Stellate|Endothelial',
#  'Stellate|Immune - Proliferating',
#  'Stellate|Malignant - Basal',
#  'Stellate|Malignant - Classical',
#  'Stellate|Malignant - IC',
#  'Stellate|Malignant - Proliferating Basal',
#  'Stellate|Malignant - Proliferating Classical',
#  'Stellate|Malignant - Proliferating IC',
#  'Stellate|Mast',
#  'Stellate|NK',
#  'Stellate|Plasma',
#  'Stellate|Stellate',
#  'Stellate|TAM - C1QC',
#  'Stellate|TAM - FCN1',
#  'Stellate|TAM - Proliferating',
#  'Stellate|TAM - SPP1',
#  'Stellate|Treg',
#  'Stellate|iCAF',
#  'Stellate|myCAF',
#  'TAM - C1QC|ADM',
#  'TAM - C1QC|Acinar',
#  'TAM - C1QC|B cell',
#  'TAM - C1QC|CD4 T cell',
#  'TAM - C1QC|CD8 T cell',
#  'TAM - C1QC|CD8 T cell - Exhausted',
#  'TAM - C1QC|DC',
#  'TAM - C1QC|Endocrine',
#  'TAM - C1QC|Endothelial',
#  'TAM - C1QC|Immune - Proliferating',
#  'TAM - C1QC|Malignant - Basal',
#  'TAM - C1QC|Malignant - Classical',
#  'TAM - C1QC|Malignant - IC',
#  'TAM - C1QC|Malignant - Proliferating Basal',
#  'TAM - C1QC|Malignant - Proliferating Classical',
#  'TAM - C1QC|Malignant - Proliferating IC',
#  'TAM - C1QC|Mast',
#  'TAM - C1QC|NK',
#  'TAM - C1QC|Plasma',
#  'TAM - C1QC|Stellate',
#  'TAM - C1QC|TAM - C1QC',
#  'TAM - C1QC|TAM - FCN1',
#  'TAM - C1QC|TAM - Proliferating',
#  'TAM - C1QC|TAM - SPP1',
#  'TAM - C1QC|Treg',
#  'TAM - C1QC|iCAF',
#  'TAM - C1QC|myCAF',
#  'TAM - FCN1|ADM',
#  'TAM - FCN1|Acinar',
#  'TAM - FCN1|B cell',
#  'TAM - FCN1|CD4 T cell',
#  'TAM - FCN1|CD8 T cell',
#  'TAM - FCN1|CD8 T cell - Exhausted',
#  'TAM - FCN1|DC',
#  'TAM - FCN1|Endocrine',
#  'TAM - FCN1|Endothelial',
#  'TAM - FCN1|Immune - Proliferating',
#  'TAM - FCN1|Malignant - Basal',
#  'TAM - FCN1|Malignant - Classical',
#  'TAM - FCN1|Malignant - IC',
#  'TAM - FCN1|Malignant - Proliferating Basal',
#  'TAM - FCN1|Malignant - Proliferating Classical',
#  'TAM - FCN1|Malignant - Proliferating IC',
#  'TAM - FCN1|Mast',
#  'TAM - FCN1|NK',
#  'TAM - FCN1|Plasma',
#  'TAM - FCN1|Stellate',
#  'TAM - FCN1|TAM - C1QC',
#  'TAM - FCN1|TAM - FCN1',
#  'TAM - FCN1|TAM - Proliferating',
#  'TAM - FCN1|TAM - SPP1',
#  'TAM - FCN1|Treg',
#  'TAM - FCN1|iCAF',
#  'TAM - FCN1|myCAF',
#  'TAM - Proliferating|ADM',
#  'TAM - Proliferating|Acinar',
#  'TAM - Proliferating|B cell',
#  'TAM - Proliferating|CD4 T cell',
#  'TAM - Proliferating|CD8 T cell',
#  'TAM - Proliferating|CD8 T cell - Exhausted',
#  'TAM - Proliferating|DC',
#  'TAM - Proliferating|Endocrine',
#  'TAM - Proliferating|Endothelial',
#  'TAM - Proliferating|Immune - Proliferating',
#  'TAM - Proliferating|Malignant - Basal',
#  'TAM - Proliferating|Malignant - Classical',
#  'TAM - Proliferating|Malignant - IC',
#  'TAM - Proliferating|Malignant - Proliferating Basal',
#  'TAM - Proliferating|Malignant - Proliferating Classical',
#  'TAM - Proliferating|Malignant - Proliferating IC',
#  'TAM - Proliferating|Mast',
#  'TAM - Proliferating|NK',
#  'TAM - Proliferating|Plasma',
#  'TAM - Proliferating|Stellate',
#  'TAM - Proliferating|TAM - C1QC',
#  'TAM - Proliferating|TAM - FCN1',
#  'TAM - Proliferating|TAM - Proliferating',
#  'TAM - Proliferating|TAM - SPP1',
#  'TAM - Proliferating|Treg',
#  'TAM - Proliferating|iCAF',
#  'TAM - Proliferating|myCAF',
#  'TAM - SPP1|ADM',
#  'TAM - SPP1|Acinar',
#  'TAM - SPP1|B cell',
#  'TAM - SPP1|CD4 T cell',
#  'TAM - SPP1|CD8 T cell',
#  'TAM - SPP1|CD8 T cell - Exhausted',
#  'TAM - SPP1|DC',
#  'TAM - SPP1|Endocrine',
#  'TAM - SPP1|Endothelial',
#  'TAM - SPP1|Immune - Proliferating',
#  'TAM - SPP1|Malignant - Basal',
#  'TAM - SPP1|Malignant - Classical',
#  'TAM - SPP1|Malignant - IC',
#  'TAM - SPP1|Malignant - Proliferating Basal',
#  'TAM - SPP1|Malignant - Proliferating Classical',
#  'TAM - SPP1|Malignant - Proliferating IC',
#  'TAM - SPP1|Mast',
#  'TAM - SPP1|NK',
#  'TAM - SPP1|Plasma',
#  'TAM - SPP1|Stellate',
#  'TAM - SPP1|TAM - C1QC',
#  'TAM - SPP1|TAM - FCN1',
#  'TAM - SPP1|TAM - Proliferating',
#  'TAM - SPP1|TAM - SPP1',
#  'TAM - SPP1|Treg',
#  'TAM - SPP1|iCAF',
#  'TAM - SPP1|myCAF',
#  'Treg|ADM',
#  'Treg|Acinar',
#  'Treg|B cell',
#  'Treg|CD4 T cell',
#  'Treg|CD8 T cell',
#  'Treg|CD8 T cell - Exhausted',
#  'Treg|DC',
#  'Treg|Endocrine',
#  'Treg|Endothelial',
#  'Treg|Immune - Proliferating',
#  'Treg|Malignant - Basal',
#  'Treg|Malignant - Classical',
#  'Treg|Malignant - IC',
#  'Treg|Malignant - Proliferating Basal',
#  'Treg|Malignant - Proliferating Classical',
#  'Treg|Malignant - Proliferating IC',
#  'Treg|Mast',
#  'Treg|NK',
#  'Treg|Plasma',
#  'Treg|Stellate',
#  'Treg|TAM - C1QC',
#  'Treg|TAM - FCN1',
#  'Treg|TAM - Proliferating',
#  'Treg|TAM - SPP1',
#  'Treg|Treg',
#  'Treg|iCAF',
#  'Treg|myCAF',
#  'iCAF|ADM',
#  'iCAF|Acinar',
#  'iCAF|B cell',
#  'iCAF|CD4 T cell',
#  'iCAF|CD8 T cell',
#  'iCAF|CD8 T cell - Exhausted',
#  'iCAF|DC',
#  'iCAF|Endocrine',
#  'iCAF|Endothelial',
#  'iCAF|Immune - Proliferating',
#  'iCAF|Malignant - Basal',
#  'iCAF|Malignant - Classical',
#  'iCAF|Malignant - IC',
#  'iCAF|Malignant - Proliferating Basal',
#  'iCAF|Malignant - Proliferating Classical',
#  'iCAF|Malignant - Proliferating IC',
#  'iCAF|Mast',
#  'iCAF|NK',
#  'iCAF|Plasma',
#  'iCAF|Stellate',
#  'iCAF|TAM - C1QC',
#  'iCAF|TAM - FCN1',
#  'iCAF|TAM - Proliferating',
#  'iCAF|TAM - SPP1',
#  'iCAF|Treg',
#  'iCAF|iCAF',
#  'iCAF|myCAF',
#  'myCAF|ADM',
#  'myCAF|Acinar',
#  'myCAF|B cell',
#  'myCAF|CD4 T cell',
#  'myCAF|CD8 T cell',
#  'myCAF|CD8 T cell - Exhausted',
#  'myCAF|DC',
#  'myCAF|Endocrine',
#  'myCAF|Endothelial',
#  'myCAF|Immune - Proliferating',
#  'myCAF|Malignant - Basal',
#  'myCAF|Malignant - Classical',
#  'myCAF|Malignant - IC',
#  'myCAF|Malignant - Proliferating Basal',
#  'myCAF|Malignant - Proliferating Classical',
#  'myCAF|Malignant - Proliferating IC',
#  'myCAF|Mast',
#  'myCAF|NK',
#  'myCAF|Plasma',
#  'myCAF|Stellate',
#  'myCAF|TAM - C1QC',
#  'myCAF|TAM - FCN1',
#  'myCAF|TAM - Proliferating',
#  'myCAF|TAM - SPP1',
#  'myCAF|Treg',
#  'myCAF|iCAF',
#  'myCAF|myCAF']

# %%
f = means[[c for c in means.columns if ('CD8 T cell - Exhausted' in c and 'Malignant' in c)]]
keep = (~pd.isnull(f)).sum(axis=1)>0
idxs = f[keep].index.to_list()
means.loc[idxs, [c for c in means.columns if ('CD8 T cell - Exhausted' in c and 'Malignant' in c) or 'gene' in c]]
# Out:
#                   gene_a   gene_b  CD8 T cell - Exhausted|Malignant - Basal  \
# id_cp_interaction
# CPI-SS034D36D2F    HLA-C    FAM3C                                     1.191
# CPI-SS055E061C9    LAMP1    FAM3C                                     0.661
# CPI-SS080611C5B    ALOX5  ALOX5AP                                       NaN
# CPI-SS00B1BEE64      CD2     CD58                                     0.784
#
#                    CD8 T cell - Exhausted|Malignant - Classical  \
# id_cp_interaction
# CPI-SS034D36D2F                                             NaN
# CPI-SS055E061C9                                             NaN
# CPI-SS080611C5B                                             NaN
# CPI-SS00B1BEE64                                            0.72
#
#                    CD8 T cell - Exhausted|Malignant - IC  \
# id_cp_interaction
# CPI-SS034D36D2F                                    1.138
# CPI-SS055E061C9                                    0.608
# CPI-SS080611C5B                                      NaN
# CPI-SS00B1BEE64                                    0.763
#
#                    CD8 T cell - Exhausted|Malignant - Proliferating Basal  \
# id_cp_interaction
# CPI-SS034D36D2F                                                  NaN
# CPI-SS055E061C9                                                  NaN
# CPI-SS080611C5B                                                  NaN
# CPI-SS00B1BEE64                                                0.777
#
#                    CD8 T cell - Exhausted|Malignant - Proliferating Classical  \
# id_cp_interaction
# CPI-SS034D36D2F                                                  NaN
# CPI-SS055E061C9                                                  NaN
# CPI-SS080611C5B                                                  NaN
# CPI-SS00B1BEE64                                                0.719
#
#                    CD8 T cell - Exhausted|Malignant - Proliferating IC  \
# id_cp_interaction
# CPI-SS034D36D2F                                                  NaN
# CPI-SS055E061C9                                                  NaN
# CPI-SS080611C5B                                                  NaN
# CPI-SS00B1BEE64                                                0.742
#
#                    Malignant - Basal|CD8 T cell - Exhausted  \
# id_cp_interaction
# CPI-SS034D36D2F                                         NaN
# CPI-SS055E061C9                                         NaN
# CPI-SS080611C5B                                       0.607
# CPI-SS00B1BEE64                                         NaN
#
#                    Malignant - Classical|CD8 T cell - Exhausted  \
# id_cp_interaction
# CPI-SS034D36D2F                                             NaN
# CPI-SS055E061C9                                             NaN
# CPI-SS080611C5B                                           0.587
# CPI-SS00B1BEE64                                             NaN
#
#                    Malignant - IC|CD8 T cell - Exhausted  \
# id_cp_interaction
# CPI-SS034D36D2F                                      NaN
# CPI-SS055E061C9                                      NaN
# CPI-SS080611C5B                                    0.643
# CPI-SS00B1BEE64                                      NaN
#
#                    Malignant - Proliferating Basal|CD8 T cell - Exhausted  \
# id_cp_interaction
# CPI-SS034D36D2F                                                  NaN
# CPI-SS055E061C9                                                  NaN
# CPI-SS080611C5B                                                  NaN
# CPI-SS00B1BEE64                                                  NaN
#
#                    Malignant - Proliferating Classical|CD8 T cell - Exhausted  \
# id_cp_interaction
# CPI-SS034D36D2F                                                  NaN
# CPI-SS055E061C9                                                  NaN
# CPI-SS080611C5B                                                0.581
# CPI-SS00B1BEE64                                                  NaN
#
#                    Malignant - Proliferating IC|CD8 T cell - Exhausted
# id_cp_interaction
# CPI-SS034D36D2F                                                  NaN
# CPI-SS055E061C9                                                  NaN
# CPI-SS080611C5B                                                0.614
# CPI-SS00B1BEE64                                                  NaN

# %%
ct = 'CD8 T cell'
f = means[[c for c in means.columns if (ct in c and 'Malignant' in c)]]
keep = (~pd.isnull(f)).sum(axis=1)>0
idxs = f[keep].index.to_list()
means.loc[idxs, [c for c in means.columns if (ct in c and 'Malignant' in c) or 'gene' in c]]
# Out:
#                   gene_a   gene_b  CD8 T cell|Malignant - Basal  \
# id_cp_interaction
# CPI-SS083CBFACD      MDK    SORL1                           NaN
# CPI-SS034D36D2F    HLA-C    FAM3C                         1.108
# CPI-SS055E061C9    LAMP1    FAM3C                         0.630
# CPI-SS080611C5B    ALOX5  ALOX5AP                           NaN
# CPI-SS00B1BEE64      CD2     CD58                         0.642
#
#                    CD8 T cell|Malignant - Classical  \
# id_cp_interaction
# CPI-SS083CBFACD                                 NaN
# CPI-SS034D36D2F                                 NaN
# CPI-SS055E061C9                                 NaN
# CPI-SS080611C5B                                 NaN
# CPI-SS00B1BEE64                               0.578
#
#                    CD8 T cell|Malignant - IC  \
# id_cp_interaction
# CPI-SS083CBFACD                          NaN
# CPI-SS034D36D2F                        1.055
# CPI-SS055E061C9                        0.577
# CPI-SS080611C5B                          NaN
# CPI-SS00B1BEE64                        0.622
#
#                    CD8 T cell|Malignant - Proliferating Basal  \
# id_cp_interaction
# CPI-SS083CBFACD                                           NaN
# CPI-SS034D36D2F                                           NaN
# CPI-SS055E061C9                                           NaN
# CPI-SS080611C5B                                           NaN
# CPI-SS00B1BEE64                                         0.636
#
#                    CD8 T cell|Malignant - Proliferating Classical  \
# id_cp_interaction
# CPI-SS083CBFACD                                               NaN
# CPI-SS034D36D2F                                               NaN
# CPI-SS055E061C9                                               NaN
# CPI-SS080611C5B                                               NaN
# CPI-SS00B1BEE64                                             0.578
#
#                    CD8 T cell|Malignant - Proliferating IC  \
# id_cp_interaction
# CPI-SS083CBFACD                                        NaN
# CPI-SS034D36D2F                                        NaN
# CPI-SS055E061C9                                        NaN
# CPI-SS080611C5B                                        NaN
# CPI-SS00B1BEE64                                      0.601
#
#                    CD8 T cell - Exhausted|Malignant - Basal  \
# id_cp_interaction
# CPI-SS083CBFACD                                         NaN
# CPI-SS034D36D2F                                       1.191
# CPI-SS055E061C9                                       0.661
# CPI-SS080611C5B                                         NaN
# CPI-SS00B1BEE64                                       0.784
#
#                    CD8 T cell - Exhausted|Malignant - Classical  ...  \
# id_cp_interaction                                                ...
# CPI-SS083CBFACD                                             NaN  ...
# CPI-SS034D36D2F                                             NaN  ...
# CPI-SS055E061C9                                             NaN  ...
# CPI-SS080611C5B                                             NaN  ...
# CPI-SS00B1BEE64                                            0.72  ...
#
#                    Malignant - Classical|CD8 T cell  \
# id_cp_interaction
# CPI-SS083CBFACD                                 NaN
# CPI-SS034D36D2F                                 NaN
# CPI-SS055E061C9                                 NaN
# CPI-SS080611C5B                               0.314
# CPI-SS00B1BEE64                                 NaN
#
#                    Malignant - Classical|CD8 T cell - Exhausted  \
# id_cp_interaction
# CPI-SS083CBFACD                                             NaN
# CPI-SS034D36D2F                                             NaN
# CPI-SS055E061C9                                             NaN
# CPI-SS080611C5B                                           0.587
# CPI-SS00B1BEE64                                             NaN
#
#                    Malignant - IC|CD8 T cell  \
# id_cp_interaction
# CPI-SS083CBFACD                        0.856
# CPI-SS034D36D2F                          NaN
# CPI-SS055E061C9                          NaN
# CPI-SS080611C5B                        0.370
# CPI-SS00B1BEE64                          NaN
#
#                    Malignant - IC|CD8 T cell - Exhausted  \
# id_cp_interaction
# CPI-SS083CBFACD                                      NaN
# CPI-SS034D36D2F                                      NaN
# CPI-SS055E061C9                                      NaN
# CPI-SS080611C5B                                    0.643
# CPI-SS00B1BEE64                                      NaN
#
#                    Malignant - Proliferating Basal|CD8 T cell  \
# id_cp_interaction
# CPI-SS083CBFACD                                           NaN
# CPI-SS034D36D2F                                           NaN
# CPI-SS055E061C9                                           NaN
# CPI-SS080611C5B                                           NaN
# CPI-SS00B1BEE64                                           NaN
#
#                    Malignant - Proliferating Basal|CD8 T cell - Exhausted  \
# id_cp_interaction
# CPI-SS083CBFACD                                                  NaN
# CPI-SS034D36D2F                                                  NaN
# CPI-SS055E061C9                                                  NaN
# CPI-SS080611C5B                                                  NaN
# CPI-SS00B1BEE64                                                  NaN
#
#                    Malignant - Proliferating Classical|CD8 T cell  \
# id_cp_interaction
# CPI-SS083CBFACD                                               NaN
# CPI-SS034D36D2F                                               NaN
# CPI-SS055E061C9                                               NaN
# CPI-SS080611C5B                                             0.308
# CPI-SS00B1BEE64                                               NaN
#
#                    Malignant - Proliferating Classical|CD8 T cell - Exhausted  \
# id_cp_interaction
# CPI-SS083CBFACD                                                  NaN
# CPI-SS034D36D2F                                                  NaN
# CPI-SS055E061C9                                                  NaN
# CPI-SS080611C5B                                                0.581
# CPI-SS00B1BEE64                                                  NaN
#
#                    Malignant - Proliferating IC|CD8 T cell  \
# id_cp_interaction
# CPI-SS083CBFACD                                        NaN
# CPI-SS034D36D2F                                        NaN
# CPI-SS055E061C9                                        NaN
# CPI-SS080611C5B                                      0.341
# CPI-SS00B1BEE64                                        NaN
#
#                    Malignant - Proliferating IC|CD8 T cell - Exhausted
# id_cp_interaction
# CPI-SS083CBFACD                                                  NaN
# CPI-SS034D36D2F                                                  NaN
# CPI-SS055E061C9                                                  NaN
# CPI-SS080611C5B                                                0.614
# CPI-SS00B1BEE64                                                  NaN
#
# [5 rows x 26 columns]
